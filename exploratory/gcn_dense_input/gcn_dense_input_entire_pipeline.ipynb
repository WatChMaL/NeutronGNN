# %%
# Network
import torch
import torch.nn.functional as F

from torch_geometric.nn import GCNConv, ChebConv
from torch_geometric.nn import global_max_pool

# Data
from torch.utils.data.sampler import SubsetRandomSampler

from torch_geometric.data import Batch, Data, Dataset, DataLoader

# General
import numpy as np

# Util
import os.path as osp
import h5py
import pickle

import time

# %% [markdown]
# # Config

# %%
# Port from https://github.com/tkarras/progressive_growing_of_gans/blob/master/config.py
class EasyDict(dict):
    def __init__(self, *args, **kwargs): super().__init__(*args, **kwargs)
    def __getattr__(self, name): return self[name]
    def __setattr__(self, name, value): self[name] = value
    def __delattr__(self, name): del self[name]

# %%
config = EasyDict()

config.model_name = "gcn_kipf"

config.data_path = "/home/jwalker/NeutronGNN/root_utils/data_1file.h5"
config.train_indices_file = "train_indicies.txt"
config.val_indices_file = "validation_indicies.txt"
config.test_indices_file = "test_indicies.txt"

config.dump_path = "dump"

config.num_data_workers = 0 # Sometime crashes if we do multiprocessing
config.device = 'gpu'
config.gpu_list = [0]

config.batch_size = 1 #32 # 256
config.lr=0.01
config.weight_decay=5e-4

config.epochs = 10
config.report_interval = 10 # 100
config.num_val_batches  = 32
config.valid_interval   = 100 # 10000

# %% [markdown]
# ### Generate fake indicies

# %%
#f=h5py.File(config.data_path,'r')
#print( f["event_data"][0] )
#print( f["nhits"][0] )
#print( f["event_data"][0, :f["nhits"][0], :] )
#length = f["event_ids"].len()
#splits = 10
#random_shuffle = np.random.permutation(length)
#validation_indicies = random_shuffle[:length//splits]
#test_indicies = random_shuffle[length//splits:2*length//splits]
#train_indicies = random_shuffle[2*length//splits:]
#
#with open("train_indicies.txt", 'w') as f:
#    f.writelines(["{}\n".format(i) for i in train_indicies])
#    
#with open("validation_indicies.txt", 'w') as f:
#    f.writelines(["{}\n".format(i) for i in validation_indicies])
#
#with open("test_indicies.txt", 'w') as f:
#    f.writelines(["{}\n".format(i) for i in test_indicies])

# %% [markdown]
# # Data Loader

# %%
class WCH5Dataset(Dataset):
    """
    Dataset storing image-like data from Water Cherenkov detector
    memory-maps the detector data from hdf5 file
    The detector data must be uncompresses and unchunked
    labels are loaded into memory outright
    No other data is currently loaded 
    """

    # Override the default implementation
    def _download(self):
        pass
    
    def _process(self):
        pass
    
    
    def __init__(self, path, train_indices_file, val_indices_file, test_indices_file, nodes=15808,
                 transform=None, pre_transform=None, pre_filter=None, 
                 use_node_attr=False, use_edge_attr=False, cleaned=False):

        super(WCH5Dataset, self).__init__("", transform, pre_transform,
                                        pre_filter)
        
        f=h5py.File(path,'r')
        hdf5_event_data = f["event_data"]
        hdf5_labels=f["labels"]
        hdf5_nhits=f["nhits"]

        assert hdf5_event_data.shape[0] == hdf5_labels.shape[0]

        event_data_shape = hdf5_event_data.shape
        event_data_offset = hdf5_event_data.id.get_offset()
        event_data_dtype = hdf5_event_data.dtype

        #this creates a memory map - i.e. events are not loaded in memory here
        #only on get_item
        self.event_data = np.memmap(path, mode='r', shape=event_data_shape, 
                                    offset=event_data_offset, dtype=event_data_dtype)
        
        #this will fit easily in memory even for huge datasets
        self.labels = np.array(hdf5_labels)
        self.nhits = np.array(hdf5_nhits)
        self.nodes = nodes
        #self.load_edges(edge_index_pickle)
        
        self.transform=transform
        
        #the section below handles the subset
        #(for reduced dataset training tests)
        #as well as shuffling and train/test/validation splits
            
        self.train_indices = self.load_indicies(train_indices_file)
        self.val_indices = self.load_indicies(val_indices_file)
        self.test_indices = self.load_indicies(test_indices_file)
    
    def load_indicies(self, indicies_file):
        with open(indicies_file, 'r') as f:
            lines = f.readlines()
        # indicies = [int(l.strip()) for l in lines if not l.isspace()]
        indicies = [int(l.strip()) for l in lines]
        return indicies
    
    def load_edges(self, nhits):
        edge_index = torch.ones([nhits, nhits], dtype=torch.int64)
        #print(edge_index)
        self.edge_index=edge_index.to_sparse()._indices()
        #print(self.edge_index)
        #print("edge_index shape", self.edge_index.shape)
    
    def get(self, idx):
        nhits = self.nhits[idx]
        x = torch.from_numpy(self.event_data[idx, :nhits, :])
        #print( x )
        #print("x shape", x.shape)
        y = torch.tensor([self.labels[idx]], dtype=torch.int64)
        self.load_edges(nhits)

        return Data(x=x, y=y, edge_index=self.edge_index)

    def __len__(self):
        return self.labels.shape[0]

# %%
def get_loaders(path, train_indices_file, val_indices_file, test_indices_file, batch_size, workers):
    
    dataset = WCH5Dataset(path, train_indices_file, val_indices_file, test_indices_file)
                          
    train_loader=DataLoader(dataset, batch_size=batch_size, num_workers=workers,
                            pin_memory=True, sampler=SubsetRandomSampler(dataset.train_indices))

    val_loader=DataLoader(dataset, batch_size=batch_size, num_workers=workers,
                            pin_memory=True, sampler=SubsetRandomSampler(dataset.val_indices))

    test_loader=DataLoader(dataset, batch_size=batch_size, num_workers=workers,
                            pin_memory=True, sampler=SubsetRandomSampler(dataset.test_indices))
    
    return train_loader, val_loader, test_loader

# %% [markdown]
# # Network stuff

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = GCNConv(8, 16, cached=False)
        self.conv2 = GCNConv(16, 16, cached=False)
        self.conv3 = GCNConv(16, 5, cached=False)

    def forward(self, batch):
        x, edge_index, batch_index = batch.x, batch.edge_index, batch.batch
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = F.relu(self.conv2(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = self.conv3(x, edge_index)
        x = global_max_pool(x, batch_index)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# # Engine

# %%
# Python standard imports
from abc import ABC, abstractmethod
from time import strftime
from os import stat, mkdir
from math import floor, ceil

# PyTorch imports
from torch import device, load, save
from torch.nn import DataParallel
from torch.cuda import is_available

# %%
class Engine(ABC):

    def __init__(self, model, config):
        super().__init__()

        # Engine attributes
        self.model=model
        self.config=config

        # Determine the device to be used for model training and inference
        if (config.device == 'gpu') and config.gpu_list:
            print("Requesting GPUs. GPU list : " + str(config.gpu_list))
            self.devids=["cuda:{0}".format(x) for x in config.gpu_list]
            print("Main GPU : " + self.devids[0])

            if is_available():
                self.device=device(self.devids[0])
                if len(self.devids) > 1:
                    print("Using DataParallel on these devices: {}".format(self.devids))
                    self.model=DataParallel(self.model, device_ids=config.gpu_list, dim=0)
                print("CUDA is available")
            else:
                self.device=device("cpu")
                print("CUDA is not available")
        else:
            print("Unable to use GPU")
            self.device=device("cpu")

        # Send the model to the selected device
        self.model = DataParallel(self.model) if len(self.devids) > 1 else self.model # Changed
        self.model.to(self.device)

        # Setup the parameters tp save given the model type
        if type(self.model) == DataParallel:
            self.model_accs=self.model.module
        else:
            self.model_accs=self.model
  
        # Create the dataset object
        out = get_loaders(config.data_path, 
                      config.train_indices_file, config.val_indices_file, config.test_indices_file,   # Changed
                      config.batch_size, config.num_data_workers)

        self.train_loader, self.val_loader, self.test_loader = out
        # Define the variant dependent attributes
        self.criterion=None

        # Create the directory for saving the log and dump files
        self.dirpath=config.dump_path + strftime("%Y%m%d_%H%M%S") + "/"
        try:
            stat(self.dirpath)
        except:
            print("Creating a directory for run dump at : {}".format(self.dirpath))
            mkdir(self.dirpath)

        # Logging attributes
        self.train_log=CSVData(self.dirpath + "log_train.csv")
        self.val_log=CSVData(self.dirpath + "log_val.csv")

#         # Save a copy of the config in the dump path
#         save_config(self.config, self.dirpath + "config_file.ini")   # changed

    @abstractmethod
    def forward(self, data, mode):
        """Forward pass using self.data as input."""
        raise NotImplementedError

    def backward(self, predict, expected):
        """Backward pass using the loss computed for a mini-batch."""
        self.optimizer.zero_grad()  # Reset gradient accumulation
        loss = self.criterion(predict, expected)
        loss.backward()# Propagate the loss backwards
        self.optimizer.step()       # Update the optimizer parameters         
        
        return loss

    @abstractmethod
    def train(self):
        """Training loop over the entire dataset for a given number of epochs."""
        raise NotImplementedError

    def save_state(self, mode="latest"):
        """Save the model parameters in a file.
        
        Args :
        mode -- one of "latest", "best" to differentiate
                the latest model from the model with the
                lowest loss on the validation subset (default "latest")
        """
        path=self.dirpath + self.config.model_name + "_" + mode + ".pth"

        # Extract modules from the model dict and add to start_dict 
        modules=list(self.model_accs._modules.keys())
        state_dict={module: getattr(self.model_accs, module).state_dict() for module in modules}

        # Save the model parameter dict
        save(state_dict, path)

    def load_state(self, path):
        """Load the model parameters from a file.
        
        Args :
        path -- absolute path to the .pth file containing the dictionary
        with the model parameters to load from
        """
        # Open a file in read-binary mode
        with open(path, 'rb') as f:

            # Interpret the file using torch.load()
            checkpoint=load(f, map_location=self.device)

            print("Loading weights from file : {0}".format(path))

            local_module_keys=list(self.model_accs._modules.keys())
            for module in checkpoint.keys():
                if module in local_module_keys:
                    print("Loading weights for module = ", module)
                    getattr(self.model_accs, module).load_state_dict(checkpoint[module])
                    
        self.model.to(self.device)

# %%
# Python standard imports
from sys import stdout
from math import floor, ceil
from time import strftime, localtime

# PyTorch imports
from torch.optim import Adam

# WatChMaL imports
# from training_utils.engine import Engine
# from plot_utils.notebook_utils import CSVData

# %%
class CSVData:

    def __init__(self,fout):
        self.name  = fout
        self._fout = None
        self._str  = None
        self._dict = {}

    def record(self, keys, vals):
        for i, key in enumerate(keys):
            self._dict[key] = vals[i]

    def write(self):
        if self._str is None:
            self._fout=open(self.name,'w')
            self._str=''
            for i,key in enumerate(self._dict.keys()):
                if i:
                    self._fout.write(',')
                    self._str += ','
                self._fout.write(key)
                self._str+='{:f}'
            self._fout.write('\n')
            self._str+='\n'

        self._fout.write(self._str.format(*(self._dict.values())))

    def flush(self):
        if self._fout: self._fout.flush()

    def close(self):
        if self._str is not None:
            self._fout.close()

# %%
class EngineGraph(Engine):

    def __init__(self, model, config):
        super().__init__(model, config)
        self.criterion=F.nll_loss
        self.optimizer=Adam(self.model_accs.parameters(), lr=config.lr)
        
        self.keys = ['iteration', 'epoch', 'loss', 'acc']

    def forward(self, data, mode="train"):
        """Overrides the forward abstract method in Engine.py.
        
        Args:
        mode -- One of 'train', 'validation' 
        """

        # Set the correct grad_mode given the mode
        if mode == "train":
            self.model.train()
        elif mode in ["validation"]:
            self.model.eval()

        return self.model(data)

    def train(self):
        """Overrides the train method in Engine.py.
        
        Args: None
        """
        
        epochs          = self.config.epochs
        report_interval = self.config.report_interval
        valid_interval  = self.config.valid_interval
        num_val_batches = self.config.num_val_batches

        # Initialize counters
        epoch=0.
        iteration=0

        # Parameter to upadte when saving the best model
        best_loss=1000000.

        val_iter = iter(self.val_loader)
        
        # Global training loop for multiple epochs
        while (floor(epoch) < epochs):

            print('Epoch', floor(epoch),
                  'Starting @', strftime("%Y-%m-%d %H:%M:%S", localtime()))

            # Local training loop for a single epoch
            for data in self.train_loader:
                #print( data )
                data = data.to(self.device)
                #print( data )

                # Update the epoch and iteration
                epoch+=1. / len(self.train_loader)
                iteration += 1
                
                # Do a forward pass using data = self.data
                res=self.forward(data, mode="train")

                # Do a backward pass using loss = self.loss
                loss = self.backward(res, data.y)

                acc = res.argmax(1).eq(data.y).sum().item()/data.y.shape[0]
                
                # Record the metrics for the mini-batch in the log
                self.train_log.record(self.keys, [iteration, epoch, loss, acc])
                self.train_log.write()

                # Print the metrics at given intervals
                if iteration % report_interval == 0:
                    print("... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Acc %1.3f"
                          % (iteration, epoch, loss, acc))

                # Run validation on given intervals
                if iteration % valid_interval == 0:
                    with torch.no_grad():
                        val_loss=0.
                        val_acc=0.

                        for val_batch in range(num_val_batches):

                            try:
                                data=next(val_iter)
                            except StopIteration:
                                val_iter=iter(self.val_loader)
                                data=next(val_iter)
                            data = data.to(self.device)

                            # Extract the event data from the input data tuple
                            res=self.forward(data, mode="validation")
                            acc = res.argmax(1).eq(data.y).sum().item()/data.y.shape[0]

                            val_loss+=self.criterion(res, data.y)
                            val_acc+=acc

                        val_loss /= num_val_batches
                        val_acc /= num_val_batches

                        # Record the validation stats to the csv
                        self.val_log.record(self.keys, [iteration, epoch, loss, acc])
                        self.val_log.write()

                        # Save the best model
                        if val_loss < best_loss:
                            self.save_state(mode="best")
                            best_loss = val_loss

                        # Save the latest model
                        self.save_state(mode="latest")
                    

        self.val_log.close()
        self.train_log.close()

    def validate(self, subset):
        """Overrides the validate method in Engine.py.
        
        Args:
        subset          -- One of 'train', 'validation', 'test' to select the subset to perform validation on
        """
        # Print start message
        if subset == "train":
            message="Validating model on the train set"
        elif subset == "validation":
            message="Validating model on the validation set"
        elif subset == "test":
            message="Validating model on the test set"
        else:
            print("validate() : arg subset has to be one of train, validation, test")
            return None

        print(message)
        
        # Setup the CSV file for logging the output, path to save the actual and reconstructed events, dataloader iterator
        if subset == "train":
            self.log=CSVData(self.dirpath + "train_validation_log.csv")
            np_event_path=self.dirpath + "/train_valid_iteration_"
            data_iter=self.train_loader
        elif subset == "validation":
            self.log=CSVData(self.dirpath + "valid_validation_log.csv")
            np_event_path=self.dirpath + "/val_valid_iteration_"
            data_iter=self.val_loader
        else:
            self.log=CSVData(self.dirpath + "test_validation_log.csv")
            np_event_path=self.dirpath + "/test_validation_iteration_"
            data_iter=self.test_loader

        save_arr_dict={"events": [], "labels": [], "energies": []}
        
        with torch.no_grad():
            for iteration, data in enumerate(data_iter):
                data = data.to(self.device)

                stdout.write("Iteration : {}, Progress {} \n".format(iteration, iteration/len(data_iter)))
                res=self.forward(data, mode="validation")
                acc = res.argmax(1).eq(data.y).sum().item()/data.y.shape[0]
                loss = self.criterion(res, data.y)

                # Log/Report
                self.log.record(["Iteration", "loss", "acc"], [iteration, loss, acc])
                self.log.write()

# %% [markdown]
# # Testing

# %% [markdown]
# ### Initiatlization

# %%
model = Net()

# %%
engine = EngineGraph(model, config)
# Out:
# Requesting GPUs. GPU list : [0]
# Main GPU : cuda:0
# CUDA is available
# Creating a directory for run dump at : dump20200203_101737/

# %% [markdown]
# ### Train

# %%
engine.train()
# Out:
# Epoch 0 Starting @ 2020-02-03 10:17:37
# ... Iteration 10 ... Epoch 0.01 ... Loss 0.000 ... Acc 1.000
# ... Iteration 20 ... Epoch 0.02 ... Loss 34.924 ... Acc 0.000
# ... Iteration 30 ... Epoch 0.02 ... Loss 47.747 ... Acc 0.000
# ... Iteration 40 ... Epoch 0.03 ... Loss 4.616 ... Acc 0.000
# ... Iteration 50 ... Epoch 0.04 ... Loss 0.000 ... Acc 1.000
# ... Iteration 60 ... Epoch 0.05 ... Loss 0.000 ... Acc 1.000
# ... Iteration 70 ... Epoch 0.05 ... Loss 1.305 ... Acc 0.000
# ... Iteration 80 ... Epoch 0.06 ... Loss 0.001 ... Acc 1.000
# ... Iteration 90 ... Epoch 0.07 ... Loss 0.800 ... Acc 0.000
# ... Iteration 100 ... Epoch 0.08 ... Loss 0.020 ... Acc 1.000
# ... Iteration 110 ... Epoch 0.08 ... Loss 0.561 ... Acc 1.000
# ... Iteration 120 ... Epoch 0.09 ... Loss 3.466 ... Acc 0.000
# ... Iteration 130 ... Epoch 0.10 ... Loss 0.863 ... Acc 0.000
# ... Iteration 140 ... Epoch 0.11 ... Loss 0.480 ... Acc 1.000
# ... Iteration 150 ... Epoch 0.11 ... Loss 0.341 ... Acc 1.000
# ... Iteration 160 ... Epoch 0.12 ... Loss 0.453 ... Acc 1.000
# ... Iteration 170 ... Epoch 0.13 ... Loss 2.609 ... Acc 0.000
# ... Iteration 180 ... Epoch 0.14 ... Loss 1.020 ... Acc 0.000
# ... Iteration 190 ... Epoch 0.15 ... Loss 0.850 ... Acc 0.000
# ... Iteration 200 ... Epoch 0.15 ... Loss 0.180 ... Acc 1.000
# ... Iteration 210 ... Epoch 0.16 ... Loss 0.917 ... Acc 0.000
# ... Iteration 220 ... Epoch 0.17 ... Loss 0.837 ... Acc 0.000
# ... Iteration 230 ... Epoch 0.18 ... Loss 1.198 ... Acc 0.000
# ... Iteration 240 ... Epoch 0.18 ... Loss 1.299 ... Acc 0.000
# ... Iteration 250 ... Epoch 0.19 ... Loss 16.848 ... Acc 0.000
# ... Iteration 260 ... Epoch 0.20 ... Loss 0.472 ... Acc 1.000
# ... Iteration 270 ... Epoch 0.21 ... Loss 0.175 ... Acc 1.000
# ... Iteration 280 ... Epoch 0.21 ... Loss 0.474 ... Acc 1.000
# ... Iteration 290 ... Epoch 0.22 ... Loss 3.203 ... Acc 0.000
# ... Iteration 300 ... Epoch 0.23 ... Loss 0.586 ... Acc 1.000
# ... Iteration 310 ... Epoch 0.24 ... Loss 0.799 ... Acc 0.000
# ... Iteration 320 ... Epoch 0.24 ... Loss 0.349 ... Acc 1.000
# ... Iteration 330 ... Epoch 0.25 ... Loss 1.434 ... Acc 0.000
# ... Iteration 340 ... Epoch 0.26 ... Loss 0.400 ... Acc 1.000
# ... Iteration 350 ... Epoch 0.27 ... Loss 1.175 ... Acc 0.000
# ... Iteration 360 ... Epoch 0.28 ... Loss 1.348 ... Acc 0.000
# ... Iteration 370 ... Epoch 0.28 ... Loss 2.790 ... Acc 0.000
# ... Iteration 380 ... Epoch 0.29 ... Loss 0.669 ... Acc 1.000
# ... Iteration 390 ... Epoch 0.30 ... Loss 0.178 ... Acc 1.000
# ... Iteration 400 ... Epoch 0.31 ... Loss 0.490 ... Acc 1.000
# ... Iteration 410 ... Epoch 0.31 ... Loss 1.550 ... Acc 0.000
# ... Iteration 420 ... Epoch 0.32 ... Loss 0.824 ... Acc 0.000
# ... Iteration 430 ... Epoch 0.33 ... Loss 0.240 ... Acc 1.000
# ... Iteration 440 ... Epoch 0.34 ... Loss 1.264 ... Acc 1.000
# ... Iteration 450 ... Epoch 0.34 ... Loss 1.274 ... Acc 0.000
# ... Iteration 460 ... Epoch 0.35 ... Loss 0.870 ... Acc 0.000
# ... Iteration 470 ... Epoch 0.36 ... Loss 1.250 ... Acc 0.000
# ... Iteration 480 ... Epoch 0.37 ... Loss 0.575 ... Acc 1.000
# ... Iteration 490 ... Epoch 0.37 ... Loss 0.842 ... Acc 0.000
# ... Iteration 500 ... Epoch 0.38 ... Loss 0.435 ... Acc 1.000
# ... Iteration 510 ... Epoch 0.39 ... Loss 0.064 ... Acc 1.000
# ... Iteration 520 ... Epoch 0.40 ... Loss 1.003 ... Acc 0.000
# ... Iteration 530 ... Epoch 0.41 ... Loss 0.710 ... Acc 1.000
# ... Iteration 540 ... Epoch 0.41 ... Loss 0.630 ... Acc 1.000
# ... Iteration 550 ... Epoch 0.42 ... Loss 0.578 ... Acc 1.000
# ... Iteration 560 ... Epoch 0.43 ... Loss 0.440 ... Acc 1.000
# ... Iteration 570 ... Epoch 0.44 ... Loss 1.013 ... Acc 0.000
# ... Iteration 580 ... Epoch 0.44 ... Loss 0.893 ... Acc 0.000
# ... Iteration 590 ... Epoch 0.45 ... Loss 0.173 ... Acc 1.000
# ... Iteration 600 ... Epoch 0.46 ... Loss 0.211 ... Acc 1.000
# ... Iteration 610 ... Epoch 0.47 ... Loss 0.623 ... Acc 1.000
# ... Iteration 620 ... Epoch 0.47 ... Loss 1.043 ... Acc 1.000
# ... Iteration 630 ... Epoch 0.48 ... Loss 1.156 ... Acc 0.000
# ... Iteration 640 ... Epoch 0.49 ... Loss 1.107 ... Acc 0.000
# ... Iteration 650 ... Epoch 0.50 ... Loss 0.735 ... Acc 0.000
# ... Iteration 660 ... Epoch 0.50 ... Loss 0.331 ... Acc 1.000
# ... Iteration 670 ... Epoch 0.51 ... Loss 0.115 ... Acc 1.000
# ... Iteration 680 ... Epoch 0.52 ... Loss 1.302 ... Acc 0.000
# ... Iteration 690 ... Epoch 0.53 ... Loss 0.644 ... Acc 1.000
# ... Iteration 700 ... Epoch 0.54 ... Loss 0.763 ... Acc 0.000
# ... Iteration 710 ... Epoch 0.54 ... Loss 0.668 ... Acc 1.000
# ... Iteration 720 ... Epoch 0.55 ... Loss 0.337 ... Acc 1.000
# ... Iteration 730 ... Epoch 0.56 ... Loss 0.723 ... Acc 0.000
# ... Iteration 740 ... Epoch 0.57 ... Loss 0.575 ... Acc 1.000
# ... Iteration 750 ... Epoch 0.57 ... Loss 1.202 ... Acc 0.000
# ... Iteration 760 ... Epoch 0.58 ... Loss 1.013 ... Acc 0.000
# ... Iteration 770 ... Epoch 0.59 ... Loss 0.995 ... Acc 0.000
# ... Iteration 780 ... Epoch 0.60 ... Loss 0.958 ... Acc 1.000
# ... Iteration 790 ... Epoch 0.60 ... Loss 0.385 ... Acc 1.000
# ... Iteration 800 ... Epoch 0.61 ... Loss 1.381 ... Acc 0.000
# ... Iteration 810 ... Epoch 0.62 ... Loss 0.880 ... Acc 0.000
# ... Iteration 820 ... Epoch 0.63 ... Loss 0.799 ... Acc 0.000
# ... Iteration 830 ... Epoch 0.63 ... Loss 0.860 ... Acc 0.000
# ... Iteration 840 ... Epoch 0.64 ... Loss 0.722 ... Acc 0.000
# ... Iteration 850 ... Epoch 0.65 ... Loss 0.922 ... Acc 0.000
# ... Iteration 860 ... Epoch 0.66 ... Loss 0.585 ... Acc 1.000
# ... Iteration 870 ... Epoch 0.67 ... Loss 0.372 ... Acc 1.000
# ... Iteration 880 ... Epoch 0.67 ... Loss 1.775 ... Acc 0.000
# ... Iteration 890 ... Epoch 0.68 ... Loss 0.713 ... Acc 0.000
# ... Iteration 900 ... Epoch 0.69 ... Loss 0.742 ... Acc 0.000
# ... Iteration 910 ... Epoch 0.70 ... Loss 0.793 ... Acc 0.000
# ... Iteration 920 ... Epoch 0.70 ... Loss 0.568 ... Acc 1.000
# ... Iteration 930 ... Epoch 0.71 ... Loss 0.632 ... Acc 1.000
# ... Iteration 940 ... Epoch 0.72 ... Loss 0.507 ... Acc 1.000
# ... Iteration 950 ... Epoch 0.73 ... Loss 0.998 ... Acc 0.000
# ... Iteration 960 ... Epoch 0.73 ... Loss 0.840 ... Acc 0.000
# ... Iteration 970 ... Epoch 0.74 ... Loss 2.581 ... Acc 0.000
# ... Iteration 980 ... Epoch 0.75 ... Loss 0.053 ... Acc 1.000
# ... Iteration 990 ... Epoch 0.76 ... Loss 0.681 ... Acc 1.000
# ... Iteration 1000 ... Epoch 0.76 ... Loss 1.034 ... Acc 0.000
# ... Iteration 1010 ... Epoch 0.77 ... Loss 0.420 ... Acc 1.000
# ... Iteration 1020 ... Epoch 0.78 ... Loss 1.548 ... Acc 0.000
# ... Iteration 1030 ... Epoch 0.79 ... Loss 0.410 ... Acc 1.000
# ... Iteration 1040 ... Epoch 0.80 ... Loss 0.573 ... Acc 1.000
# ... Iteration 1050 ... Epoch 0.80 ... Loss 0.839 ... Acc 0.000
# ... Iteration 1060 ... Epoch 0.81 ... Loss 0.738 ... Acc 0.000
# ... Iteration 1070 ... Epoch 0.82 ... Loss 0.671 ... Acc 1.000
# ... Iteration 1080 ... Epoch 0.83 ... Loss 0.975 ... Acc 0.000
# ... Iteration 1090 ... Epoch 0.83 ... Loss 0.559 ... Acc 1.000
# ... Iteration 1100 ... Epoch 0.84 ... Loss 0.924 ... Acc 0.000
# ... Iteration 1110 ... Epoch 0.85 ... Loss 0.852 ... Acc 0.000
# ... Iteration 1120 ... Epoch 0.86 ... Loss 0.856 ... Acc 0.000
# ... Iteration 1130 ... Epoch 0.86 ... Loss 0.699 ... Acc 0.000
# ... Iteration 1140 ... Epoch 0.87 ... Loss 1.023 ... Acc 0.000
# ... Iteration 1150 ... Epoch 0.88 ... Loss 0.538 ... Acc 1.000
# ... Iteration 1160 ... Epoch 0.89 ... Loss 0.721 ... Acc 0.000
# ... Iteration 1170 ... Epoch 0.89 ... Loss 0.947 ... Acc 0.000
# ... Iteration 1180 ... Epoch 0.90 ... Loss 0.757 ... Acc 0.000
# ... Iteration 1190 ... Epoch 0.91 ... Loss 0.772 ... Acc 0.000
# ... Iteration 1200 ... Epoch 0.92 ... Loss 0.586 ... Acc 1.000
# ... Iteration 1210 ... Epoch 0.93 ... Loss 0.725 ... Acc 0.000
# ... Iteration 1220 ... Epoch 0.93 ... Loss 1.031 ... Acc 0.000
# ... Iteration 1230 ... Epoch 0.94 ... Loss 0.731 ... Acc 0.000
# ... Iteration 1240 ... Epoch 0.95 ... Loss 0.745 ... Acc 0.000
# ... Iteration 1250 ... Epoch 0.96 ... Loss 0.810 ... Acc 0.000
# ... Iteration 1260 ... Epoch 0.96 ... Loss 0.875 ... Acc 0.000
# ... Iteration 1270 ... Epoch 0.97 ... Loss 0.736 ... Acc 1.000
# ... Iteration 1280 ... Epoch 0.98 ... Loss 0.787 ... Acc 0.000
# ... Iteration 1290 ... Epoch 0.99 ... Loss 0.834 ... Acc 0.000
# ... Iteration 1300 ... Epoch 0.99 ... Loss 0.710 ... Acc 0.000
# Epoch 0 Starting @ 2020-02-03 10:17:54
# ... Iteration 1310 ... Epoch 1.00 ... Loss 0.763 ... Acc 0.000
# ... Iteration 1320 ... Epoch 1.01 ... Loss 0.716 ... Acc 0.000
# ... Iteration 1330 ... Epoch 1.02 ... Loss 0.726 ... Acc 0.000
# ... Iteration 1340 ... Epoch 1.02 ... Loss 0.659 ... Acc 1.000
# ... Iteration 1350 ... Epoch 1.03 ... Loss 1.150 ... Acc 0.000
# ... Iteration 1360 ... Epoch 1.04 ... Loss 0.429 ... Acc 1.000
# ... Iteration 1370 ... Epoch 1.05 ... Loss 0.800 ... Acc 0.000
# ... Iteration 1380 ... Epoch 1.06 ... Loss 0.687 ... Acc 1.000
# ... Iteration 1390 ... Epoch 1.06 ... Loss 0.768 ... Acc 0.000
# ... Iteration 1400 ... Epoch 1.07 ... Loss 0.732 ... Acc 0.000
# ... Iteration 1410 ... Epoch 1.08 ... Loss 0.696 ... Acc 0.000
# ... Iteration 1420 ... Epoch 1.09 ... Loss 0.651 ... Acc 1.000
# ... Iteration 1430 ... Epoch 1.09 ... Loss 0.646 ... Acc 1.000
# ... Iteration 1440 ... Epoch 1.10 ... Loss 0.678 ... Acc 1.000
# ... Iteration 1450 ... Epoch 1.11 ... Loss 0.737 ... Acc 0.000
# ... Iteration 1460 ... Epoch 1.12 ... Loss 0.705 ... Acc 0.000
# ... Iteration 1470 ... Epoch 1.12 ... Loss 0.977 ... Acc 0.000
# ... Iteration 1480 ... Epoch 1.13 ... Loss 0.901 ... Acc 0.000
# ... Iteration 1490 ... Epoch 1.14 ... Loss 0.773 ... Acc 0.000
# ... Iteration 1500 ... Epoch 1.15 ... Loss 0.611 ... Acc 1.000
# ... Iteration 1510 ... Epoch 1.15 ... Loss 1.141 ... Acc 0.000
# ... Iteration 1520 ... Epoch 1.16 ... Loss 0.501 ... Acc 1.000
# ... Iteration 1530 ... Epoch 1.17 ... Loss 0.618 ... Acc 1.000
# ... Iteration 1540 ... Epoch 1.18 ... Loss 0.726 ... Acc 0.000
# ... Iteration 1550 ... Epoch 1.19 ... Loss 0.743 ... Acc 0.000
# ... Iteration 1560 ... Epoch 1.19 ... Loss 0.773 ... Acc 0.000
# ... Iteration 1570 ... Epoch 1.20 ... Loss 0.630 ... Acc 1.000
# ... Iteration 1580 ... Epoch 1.21 ... Loss 0.664 ... Acc 1.000
# ... Iteration 1590 ... Epoch 1.22 ... Loss 0.762 ... Acc 0.000
# ... Iteration 1600 ... Epoch 1.22 ... Loss 0.804 ... Acc 0.000
# ... Iteration 1610 ... Epoch 1.23 ... Loss 0.601 ... Acc 1.000
# ... Iteration 1620 ... Epoch 1.24 ... Loss 0.643 ... Acc 1.000
# ... Iteration 1630 ... Epoch 1.25 ... Loss 0.743 ... Acc 0.000
# ... Iteration 1640 ... Epoch 1.25 ... Loss 0.790 ... Acc 0.000
# ... Iteration 1650 ... Epoch 1.26 ... Loss 0.574 ... Acc 1.000
# ... Iteration 1660 ... Epoch 1.27 ... Loss 1.042 ... Acc 0.000
# ... Iteration 1670 ... Epoch 1.28 ... Loss 1.432 ... Acc 0.000
# ... Iteration 1680 ... Epoch 1.28 ... Loss 1.331 ... Acc 0.000
# ... Iteration 1690 ... Epoch 1.29 ... Loss 0.851 ... Acc 0.000
# ... Iteration 1700 ... Epoch 1.30 ... Loss 0.728 ... Acc 0.000
# ... Iteration 1710 ... Epoch 1.31 ... Loss 0.824 ... Acc 0.000
# ... Iteration 1720 ... Epoch 1.31 ... Loss 0.689 ... Acc 1.000
# ... Iteration 1730 ... Epoch 1.32 ... Loss 0.646 ... Acc 1.000
# ... Iteration 1740 ... Epoch 1.33 ... Loss 0.304 ... Acc 1.000
# ... Iteration 1750 ... Epoch 1.34 ... Loss 0.037 ... Acc 1.000
# ... Iteration 1760 ... Epoch 1.35 ... Loss 0.599 ... Acc 1.000
# ... Iteration 1770 ... Epoch 1.35 ... Loss 0.636 ... Acc 1.000
# ... Iteration 1780 ... Epoch 1.36 ... Loss 0.291 ... Acc 1.000
# ... Iteration 1790 ... Epoch 1.37 ... Loss 0.236 ... Acc 1.000
# ... Iteration 1800 ... Epoch 1.38 ... Loss 0.791 ... Acc 0.000
# ... Iteration 1810 ... Epoch 1.38 ... Loss 0.727 ... Acc 0.000
# ... Iteration 1820 ... Epoch 1.39 ... Loss 0.797 ... Acc 0.000
# ... Iteration 1830 ... Epoch 1.40 ... Loss 0.846 ... Acc 0.000
# ... Iteration 1840 ... Epoch 1.41 ... Loss 0.596 ... Acc 1.000
# ... Iteration 1850 ... Epoch 1.41 ... Loss 0.640 ... Acc 1.000
# ... Iteration 1860 ... Epoch 1.42 ... Loss 0.725 ... Acc 0.000
# ... Iteration 1870 ... Epoch 1.43 ... Loss 0.700 ... Acc 0.000
# ... Iteration 1880 ... Epoch 1.44 ... Loss 0.813 ... Acc 0.000
# ... Iteration 1890 ... Epoch 1.44 ... Loss 0.685 ... Acc 1.000
# ... Iteration 1900 ... Epoch 1.45 ... Loss 1.014 ... Acc 0.000
# ... Iteration 1910 ... Epoch 1.46 ... Loss 0.755 ... Acc 0.000
# ... Iteration 1920 ... Epoch 1.47 ... Loss 0.602 ... Acc 1.000
# ... Iteration 1930 ... Epoch 1.48 ... Loss 0.770 ... Acc 0.000
# ... Iteration 1940 ... Epoch 1.48 ... Loss 0.606 ... Acc 1.000
# ... Iteration 1950 ... Epoch 1.49 ... Loss 0.605 ... Acc 1.000
# ... Iteration 1960 ... Epoch 1.50 ... Loss 0.709 ... Acc 0.000
# ... Iteration 1970 ... Epoch 1.51 ... Loss 0.699 ... Acc 0.000
# ... Iteration 1980 ... Epoch 1.51 ... Loss 0.674 ... Acc 1.000
# ... Iteration 1990 ... Epoch 1.52 ... Loss 0.689 ... Acc 1.000
# ... Iteration 2000 ... Epoch 1.53 ... Loss 0.759 ... Acc 0.000
# ... Iteration 2010 ... Epoch 1.54 ... Loss 0.924 ... Acc 0.000
# ... Iteration 2020 ... Epoch 1.54 ... Loss 0.776 ... Acc 0.000
# ... Iteration 2030 ... Epoch 1.55 ... Loss 0.734 ... Acc 0.000
# ... Iteration 2040 ... Epoch 1.56 ... Loss 0.592 ... Acc 1.000
# ... Iteration 2050 ... Epoch 1.57 ... Loss 0.908 ... Acc 0.000
# ... Iteration 2060 ... Epoch 1.57 ... Loss 0.803 ... Acc 0.000
# ... Iteration 2070 ... Epoch 1.58 ... Loss 0.565 ... Acc 1.000
# ... Iteration 2080 ... Epoch 1.59 ... Loss 0.825 ... Acc 0.000
# ... Iteration 2090 ... Epoch 1.60 ... Loss 0.772 ... Acc 0.000
# ... Iteration 2100 ... Epoch 1.61 ... Loss 0.739 ... Acc 0.000
# ... Iteration 2110 ... Epoch 1.61 ... Loss 0.664 ... Acc 1.000
# ... Iteration 2120 ... Epoch 1.62 ... Loss 0.648 ... Acc 1.000
# ... Iteration 2130 ... Epoch 1.63 ... Loss 0.584 ... Acc 1.000
# ... Iteration 2140 ... Epoch 1.64 ... Loss 0.931 ... Acc 0.000
# ... Iteration 2150 ... Epoch 1.64 ... Loss 0.608 ... Acc 1.000
# ... Iteration 2160 ... Epoch 1.65 ... Loss 0.776 ... Acc 0.000
# ... Iteration 2170 ... Epoch 1.66 ... Loss 0.668 ... Acc 1.000
# ... Iteration 2180 ... Epoch 1.67 ... Loss 0.734 ... Acc 0.000
# ... Iteration 2190 ... Epoch 1.67 ... Loss 0.646 ... Acc 1.000
# ... Iteration 2200 ... Epoch 1.68 ... Loss 0.429 ... Acc 1.000
# ... Iteration 2210 ... Epoch 1.69 ... Loss 0.935 ... Acc 0.000
# ... Iteration 2220 ... Epoch 1.70 ... Loss 0.677 ... Acc 1.000
# ... Iteration 2230 ... Epoch 1.70 ... Loss 0.743 ... Acc 0.000
# ... Iteration 2240 ... Epoch 1.71 ... Loss 0.664 ... Acc 1.000
# ... Iteration 2250 ... Epoch 1.72 ... Loss 0.699 ... Acc 0.000
# ... Iteration 2260 ... Epoch 1.73 ... Loss 0.645 ... Acc 1.000
# ... Iteration 2270 ... Epoch 1.74 ... Loss 0.647 ... Acc 1.000
# ... Iteration 2280 ... Epoch 1.74 ... Loss 0.557 ... Acc 1.000
# ... Iteration 2290 ... Epoch 1.75 ... Loss 0.706 ... Acc 0.000
# ... Iteration 2300 ... Epoch 1.76 ... Loss 0.774 ... Acc 0.000
# ... Iteration 2310 ... Epoch 1.77 ... Loss 0.800 ... Acc 0.000
# ... Iteration 2320 ... Epoch 1.77 ... Loss 0.580 ... Acc 1.000
# ... Iteration 2330 ... Epoch 1.78 ... Loss 1.012 ... Acc 0.000
# ... Iteration 2340 ... Epoch 1.79 ... Loss 0.940 ... Acc 0.000
# ... Iteration 2350 ... Epoch 1.80 ... Loss 0.437 ... Acc 1.000
# ... Iteration 2360 ... Epoch 1.80 ... Loss 0.554 ... Acc 1.000
# ... Iteration 2370 ... Epoch 1.81 ... Loss 0.962 ... Acc 0.000
# ... Iteration 2380 ... Epoch 1.82 ... Loss 0.613 ... Acc 1.000
# ... Iteration 2390 ... Epoch 1.83 ... Loss 0.695 ... Acc 0.000
# ... Iteration 2400 ... Epoch 1.83 ... Loss 0.680 ... Acc 1.000
# ... Iteration 2410 ... Epoch 1.84 ... Loss 0.768 ... Acc 0.000
# ... Iteration 2420 ... Epoch 1.85 ... Loss 0.772 ... Acc 0.000
# ... Iteration 2430 ... Epoch 1.86 ... Loss 0.772 ... Acc 0.000
# ... Iteration 2440 ... Epoch 1.87 ... Loss 0.643 ... Acc 1.000
# ... Iteration 2450 ... Epoch 1.87 ... Loss 0.725 ... Acc 0.000
# ... Iteration 2460 ... Epoch 1.88 ... Loss 0.642 ... Acc 1.000
# ... Iteration 2470 ... Epoch 1.89 ... Loss 0.805 ... Acc 0.000
# ... Iteration 2480 ... Epoch 1.90 ... Loss 0.755 ... Acc 0.000
# ... Iteration 2490 ... Epoch 1.90 ... Loss 0.688 ... Acc 1.000
# ... Iteration 2500 ... Epoch 1.91 ... Loss 0.688 ... Acc 1.000
# ... Iteration 2510 ... Epoch 1.92 ... Loss 0.685 ... Acc 1.000
# ... Iteration 2520 ... Epoch 1.93 ... Loss 0.740 ... Acc 0.000
# ... Iteration 2530 ... Epoch 1.93 ... Loss 0.670 ... Acc 1.000
# ... Iteration 2540 ... Epoch 1.94 ... Loss 0.684 ... Acc 1.000
# ... Iteration 2550 ... Epoch 1.95 ... Loss 0.506 ... Acc 1.000
# ... Iteration 2560 ... Epoch 1.96 ... Loss 0.603 ... Acc 1.000
# ... Iteration 2570 ... Epoch 1.96 ... Loss 0.672 ... Acc 1.000
# ... Iteration 2580 ... Epoch 1.97 ... Loss 0.630 ... Acc 1.000
# ... Iteration 2590 ... Epoch 1.98 ... Loss 0.558 ... Acc 1.000
# ... Iteration 2600 ... Epoch 1.99 ... Loss 0.685 ... Acc 1.000
# ... Iteration 2610 ... Epoch 2.00 ... Loss 0.770 ... Acc 0.000
# Epoch 1 Starting @ 2020-02-03 10:18:09
# ... Iteration 2620 ... Epoch 2.00 ... Loss 0.671 ... Acc 1.000
# ... Iteration 2630 ... Epoch 2.01 ... Loss 0.590 ... Acc 1.000
# ... Iteration 2640 ... Epoch 2.02 ... Loss 0.694 ... Acc 1.000
# ... Iteration 2650 ... Epoch 2.03 ... Loss 0.670 ... Acc 1.000
# ... Iteration 2660 ... Epoch 2.03 ... Loss 0.884 ... Acc 0.000
# ... Iteration 2670 ... Epoch 2.04 ... Loss 0.624 ... Acc 1.000
# ... Iteration 2680 ... Epoch 2.05 ... Loss 0.778 ... Acc 0.000
# ... Iteration 2690 ... Epoch 2.06 ... Loss 0.777 ... Acc 0.000
# ... Iteration 2700 ... Epoch 2.06 ... Loss 0.663 ... Acc 1.000
# ... Iteration 2710 ... Epoch 2.07 ... Loss 0.929 ... Acc 0.000
# ... Iteration 2720 ... Epoch 2.08 ... Loss 0.946 ... Acc 0.000
# ... Iteration 2730 ... Epoch 2.09 ... Loss 0.820 ... Acc 0.000
# ... Iteration 2740 ... Epoch 2.09 ... Loss 0.808 ... Acc 0.000
# ... Iteration 2750 ... Epoch 2.10 ... Loss 0.927 ... Acc 0.000
# ... Iteration 2760 ... Epoch 2.11 ... Loss 0.716 ... Acc 0.000
# ... Iteration 2770 ... Epoch 2.12 ... Loss 0.670 ... Acc 1.000
# ... Iteration 2780 ... Epoch 2.13 ... Loss 0.635 ... Acc 1.000
# ... Iteration 2790 ... Epoch 2.13 ... Loss 0.663 ... Acc 1.000
# ... Iteration 2800 ... Epoch 2.14 ... Loss 0.666 ... Acc 1.000
# ... Iteration 2810 ... Epoch 2.15 ... Loss 0.767 ... Acc 0.000
# ... Iteration 2820 ... Epoch 2.16 ... Loss 0.560 ... Acc 1.000
# ... Iteration 2830 ... Epoch 2.16 ... Loss 0.225 ... Acc 1.000
# ... Iteration 2840 ... Epoch 2.17 ... Loss 0.610 ... Acc 1.000
# ... Iteration 2850 ... Epoch 2.18 ... Loss 0.882 ... Acc 0.000
# ... Iteration 2860 ... Epoch 2.19 ... Loss 1.119 ... Acc 0.000
# ... Iteration 2870 ... Epoch 2.19 ... Loss 0.767 ... Acc 0.000
# ... Iteration 2880 ... Epoch 2.20 ... Loss 0.953 ... Acc 0.000
# ... Iteration 2890 ... Epoch 2.21 ... Loss 0.553 ... Acc 1.000
# ... Iteration 2900 ... Epoch 2.22 ... Loss 0.619 ... Acc 1.000
# ... Iteration 2910 ... Epoch 2.22 ... Loss 0.838 ... Acc 0.000
# ... Iteration 2920 ... Epoch 2.23 ... Loss 0.625 ... Acc 1.000
# ... Iteration 2930 ... Epoch 2.24 ... Loss 0.775 ... Acc 0.000
# ... Iteration 2940 ... Epoch 2.25 ... Loss 1.052 ... Acc 0.000
# ... Iteration 2950 ... Epoch 2.26 ... Loss 0.657 ... Acc 1.000
# ... Iteration 2960 ... Epoch 2.26 ... Loss 0.585 ... Acc 1.000
# ... Iteration 2970 ... Epoch 2.27 ... Loss 0.833 ... Acc 0.000
# ... Iteration 2980 ... Epoch 2.28 ... Loss 0.712 ... Acc 0.000
# ... Iteration 2990 ... Epoch 2.29 ... Loss 0.571 ... Acc 1.000
# ... Iteration 3000 ... Epoch 2.29 ... Loss 0.750 ... Acc 0.000
# ... Iteration 3010 ... Epoch 2.30 ... Loss 0.761 ... Acc 0.000
# ... Iteration 3020 ... Epoch 2.31 ... Loss 0.735 ... Acc 0.000
# ... Iteration 3030 ... Epoch 2.32 ... Loss 0.832 ... Acc 0.000
# ... Iteration 3040 ... Epoch 2.32 ... Loss 0.595 ... Acc 1.000
# ... Iteration 3050 ... Epoch 2.33 ... Loss 0.793 ... Acc 0.000
# ... Iteration 3060 ... Epoch 2.34 ... Loss 0.679 ... Acc 1.000
# ... Iteration 3070 ... Epoch 2.35 ... Loss 0.899 ... Acc 0.000
# ... Iteration 3080 ... Epoch 2.35 ... Loss 0.769 ... Acc 0.000
# ... Iteration 3090 ... Epoch 2.36 ... Loss 0.707 ... Acc 0.000
# ... Iteration 3100 ... Epoch 2.37 ... Loss 0.680 ... Acc 1.000
# ... Iteration 3110 ... Epoch 2.38 ... Loss 0.726 ... Acc 0.000
# ... Iteration 3120 ... Epoch 2.39 ... Loss 0.692 ... Acc 1.000
# ... Iteration 3130 ... Epoch 2.39 ... Loss 0.694 ... Acc 0.000
# ... Iteration 3140 ... Epoch 2.40 ... Loss 0.732 ... Acc 0.000
# ... Iteration 3150 ... Epoch 2.41 ... Loss 0.646 ... Acc 1.000
# ... Iteration 3160 ... Epoch 2.42 ... Loss 0.603 ... Acc 1.000
# ... Iteration 3170 ... Epoch 2.42 ... Loss 0.446 ... Acc 1.000
# ... Iteration 3180 ... Epoch 2.43 ... Loss 0.592 ... Acc 1.000
# ... Iteration 3190 ... Epoch 2.44 ... Loss 0.827 ... Acc 0.000
# ... Iteration 3200 ... Epoch 2.45 ... Loss 0.838 ... Acc 0.000
# ... Iteration 3210 ... Epoch 2.45 ... Loss 0.897 ... Acc 0.000
# ... Iteration 3220 ... Epoch 2.46 ... Loss 0.648 ... Acc 1.000
# ... Iteration 3230 ... Epoch 2.47 ... Loss 0.559 ... Acc 1.000
# ... Iteration 3240 ... Epoch 2.48 ... Loss 3.149 ... Acc 0.000
# ... Iteration 3250 ... Epoch 2.48 ... Loss 0.769 ... Acc 1.000
# ... Iteration 3260 ... Epoch 2.49 ... Loss 0.739 ... Acc 1.000
# ... Iteration 3270 ... Epoch 2.50 ... Loss 0.705 ... Acc 1.000
# ... Iteration 3280 ... Epoch 2.51 ... Loss 0.827 ... Acc 0.000
# ... Iteration 3290 ... Epoch 2.52 ... Loss 0.809 ... Acc 0.000
# ... Iteration 3300 ... Epoch 2.52 ... Loss 0.692 ... Acc 1.000
# ... Iteration 3310 ... Epoch 2.53 ... Loss 0.762 ... Acc 0.000
# ... Iteration 3320 ... Epoch 2.54 ... Loss 0.752 ... Acc 0.000
# ... Iteration 3330 ... Epoch 2.55 ... Loss 0.736 ... Acc 0.000
# ... Iteration 3340 ... Epoch 2.55 ... Loss 0.687 ... Acc 1.000
# ... Iteration 3350 ... Epoch 2.56 ... Loss 0.782 ... Acc 0.000
# ... Iteration 3360 ... Epoch 2.57 ... Loss 0.744 ... Acc 0.000
# ... Iteration 3370 ... Epoch 2.58 ... Loss 0.691 ... Acc 1.000
# ... Iteration 3380 ... Epoch 2.58 ... Loss 0.790 ... Acc 0.000
# ... Iteration 3390 ... Epoch 2.59 ... Loss 0.624 ... Acc 1.000
# ... Iteration 3400 ... Epoch 2.60 ... Loss 0.803 ... Acc 0.000
# ... Iteration 3410 ... Epoch 2.61 ... Loss 0.775 ... Acc 0.000
# ... Iteration 3420 ... Epoch 2.61 ... Loss 0.753 ... Acc 0.000
# ... Iteration 3430 ... Epoch 2.62 ... Loss 0.727 ... Acc 0.000
# ... Iteration 3440 ... Epoch 2.63 ... Loss 0.709 ... Acc 0.000
# ... Iteration 3450 ... Epoch 2.64 ... Loss 0.731 ... Acc 0.000
# ... Iteration 3460 ... Epoch 2.65 ... Loss 0.674 ... Acc 1.000
# ... Iteration 3470 ... Epoch 2.65 ... Loss 0.740 ... Acc 0.000
# ... Iteration 3480 ... Epoch 2.66 ... Loss 0.690 ... Acc 1.000
# ... Iteration 3490 ... Epoch 2.67 ... Loss 0.731 ... Acc 0.000
# ... Iteration 3500 ... Epoch 2.68 ... Loss 0.660 ... Acc 1.000
# ... Iteration 3510 ... Epoch 2.68 ... Loss 0.654 ... Acc 1.000
# ... Iteration 3520 ... Epoch 2.69 ... Loss 0.650 ... Acc 1.000
# ... Iteration 3530 ... Epoch 2.70 ... Loss 0.786 ... Acc 0.000
# ... Iteration 3540 ... Epoch 2.71 ... Loss 0.798 ... Acc 0.000
# ... Iteration 3550 ... Epoch 2.71 ... Loss 0.626 ... Acc 1.000
# ... Iteration 3560 ... Epoch 2.72 ... Loss 0.775 ... Acc 0.000
# ... Iteration 3570 ... Epoch 2.73 ... Loss 0.766 ... Acc 0.000
# ... Iteration 3580 ... Epoch 2.74 ... Loss 0.782 ... Acc 0.000
# ... Iteration 3590 ... Epoch 2.74 ... Loss 0.800 ... Acc 0.000
# ... Iteration 3600 ... Epoch 2.75 ... Loss 0.600 ... Acc 1.000
# ... Iteration 3610 ... Epoch 2.76 ... Loss 0.585 ... Acc 1.000
# ... Iteration 3620 ... Epoch 2.77 ... Loss 0.590 ... Acc 1.000
# ... Iteration 3630 ... Epoch 2.78 ... Loss 0.584 ... Acc 1.000
# ... Iteration 3640 ... Epoch 2.78 ... Loss 0.573 ... Acc 1.000
# ... Iteration 3650 ... Epoch 2.79 ... Loss 0.543 ... Acc 1.000
# ... Iteration 3660 ... Epoch 2.80 ... Loss 0.930 ... Acc 0.000
# ... Iteration 3670 ... Epoch 2.81 ... Loss 0.512 ... Acc 1.000
# ... Iteration 3680 ... Epoch 2.81 ... Loss 0.518 ... Acc 1.000
# ... Iteration 3690 ... Epoch 2.82 ... Loss 0.537 ... Acc 1.000
# ... Iteration 3700 ... Epoch 2.83 ... Loss 0.546 ... Acc 1.000
# ... Iteration 3710 ... Epoch 2.84 ... Loss 0.551 ... Acc 1.000
# ... Iteration 3720 ... Epoch 2.84 ... Loss 0.862 ... Acc 0.000
# ... Iteration 3730 ... Epoch 2.85 ... Loss 0.577 ... Acc 1.000
# ... Iteration 3740 ... Epoch 2.86 ... Loss 0.584 ... Acc 1.000
# ... Iteration 3750 ... Epoch 2.87 ... Loss 0.838 ... Acc 0.000
# ... Iteration 3760 ... Epoch 2.87 ... Loss 0.824 ... Acc 0.000
# ... Iteration 3770 ... Epoch 2.88 ... Loss 0.613 ... Acc 1.000
# ... Iteration 3780 ... Epoch 2.89 ... Loss 0.773 ... Acc 0.000
# ... Iteration 3790 ... Epoch 2.90 ... Loss 0.750 ... Acc 0.000
# ... Iteration 3800 ... Epoch 2.91 ... Loss 0.732 ... Acc 0.000
# ... Iteration 3810 ... Epoch 2.91 ... Loss 0.673 ... Acc 1.000
# ... Iteration 3820 ... Epoch 2.92 ... Loss 0.758 ... Acc 0.000
# ... Iteration 3830 ... Epoch 2.93 ... Loss 0.759 ... Acc 0.000
# ... Iteration 3840 ... Epoch 2.94 ... Loss 0.665 ... Acc 1.000
# ... Iteration 3850 ... Epoch 2.94 ... Loss 0.694 ... Acc 1.000
# ... Iteration 3860 ... Epoch 2.95 ... Loss 0.690 ... Acc 1.000
# ... Iteration 3870 ... Epoch 2.96 ... Loss 0.672 ... Acc 1.000
# ... Iteration 3880 ... Epoch 2.97 ... Loss 0.734 ... Acc 0.000
# ... Iteration 3890 ... Epoch 2.97 ... Loss 0.724 ... Acc 0.000
# ... Iteration 3900 ... Epoch 2.98 ... Loss 0.668 ... Acc 1.000
# ... Iteration 3910 ... Epoch 2.99 ... Loss 0.662 ... Acc 1.000
# ... Iteration 3920 ... Epoch 3.00 ... Loss 0.727 ... Acc 0.000
# Epoch 2 Starting @ 2020-02-03 10:18:25
# ... Iteration 3930 ... Epoch 3.00 ... Loss 0.707 ... Acc 0.000
# ... Iteration 3940 ... Epoch 3.01 ... Loss 0.707 ... Acc 0.000
# ... Iteration 3950 ... Epoch 3.02 ... Loss 0.710 ... Acc 0.000
# ... Iteration 3960 ... Epoch 3.03 ... Loss 0.696 ... Acc 1.000
# ... Iteration 3970 ... Epoch 3.04 ... Loss 0.709 ... Acc 0.000
# ... Iteration 3980 ... Epoch 3.04 ... Loss 0.681 ... Acc 1.000
# ... Iteration 3990 ... Epoch 3.05 ... Loss 0.692 ... Acc 1.000
# ... Iteration 4000 ... Epoch 3.06 ... Loss 0.728 ... Acc 0.000
# ... Iteration 4010 ... Epoch 3.07 ... Loss 0.674 ... Acc 1.000
# ... Iteration 4020 ... Epoch 3.07 ... Loss 0.678 ... Acc 1.000
# ... Iteration 4030 ... Epoch 3.08 ... Loss 0.668 ... Acc 1.000
# ... Iteration 4040 ... Epoch 3.09 ... Loss 0.726 ... Acc 0.000
# ... Iteration 4050 ... Epoch 3.10 ... Loss 0.702 ... Acc 0.000
# ... Iteration 4060 ... Epoch 3.10 ... Loss 0.714 ... Acc 0.000
# ... Iteration 4070 ... Epoch 3.11 ... Loss 0.740 ... Acc 0.000
# ... Iteration 4080 ... Epoch 3.12 ... Loss 0.733 ... Acc 0.000
# ... Iteration 4090 ... Epoch 3.13 ... Loss 0.653 ... Acc 1.000
# ... Iteration 4100 ... Epoch 3.13 ... Loss 0.793 ... Acc 0.000
# ... Iteration 4110 ... Epoch 3.14 ... Loss 0.598 ... Acc 1.000
# ... Iteration 4120 ... Epoch 3.15 ... Loss 0.624 ... Acc 1.000
# ... Iteration 4130 ... Epoch 3.16 ... Loss 0.782 ... Acc 0.000
# ... Iteration 4140 ... Epoch 3.17 ... Loss 0.610 ... Acc 1.000
# ... Iteration 4150 ... Epoch 3.17 ... Loss 0.806 ... Acc 0.000
# ... Iteration 4160 ... Epoch 3.18 ... Loss 0.791 ... Acc 0.000
# ... Iteration 4170 ... Epoch 3.19 ... Loss 0.660 ... Acc 1.000
# ... Iteration 4180 ... Epoch 3.20 ... Loss 0.701 ... Acc 0.000
# ... Iteration 4190 ... Epoch 3.20 ... Loss 0.693 ... Acc 1.000
# ... Iteration 4200 ... Epoch 3.21 ... Loss 0.686 ... Acc 1.000
# ... Iteration 4210 ... Epoch 3.22 ... Loss 0.729 ... Acc 0.000
# ... Iteration 4220 ... Epoch 3.23 ... Loss 0.722 ... Acc 0.000
# ... Iteration 4230 ... Epoch 3.23 ... Loss 0.733 ... Acc 0.000
# ... Iteration 4240 ... Epoch 3.24 ... Loss 0.668 ... Acc 1.000
# ... Iteration 4250 ... Epoch 3.25 ... Loss 0.712 ... Acc 0.000
# ... Iteration 4260 ... Epoch 3.26 ... Loss 0.700 ... Acc 0.000
# ... Iteration 4270 ... Epoch 3.26 ... Loss 0.694 ... Acc 1.000
# ... Iteration 4280 ... Epoch 3.27 ... Loss 0.711 ... Acc 0.000
# ... Iteration 4290 ... Epoch 3.28 ... Loss 0.725 ... Acc 0.000
# ... Iteration 4300 ... Epoch 3.29 ... Loss 0.640 ... Acc 1.000
# ... Iteration 4310 ... Epoch 3.30 ... Loss 0.629 ... Acc 1.000
# ... Iteration 4320 ... Epoch 3.30 ... Loss 0.625 ... Acc 1.000
# ... Iteration 4330 ... Epoch 3.31 ... Loss 0.770 ... Acc 0.000
# ... Iteration 4340 ... Epoch 3.32 ... Loss 0.762 ... Acc 0.000
# ... Iteration 4350 ... Epoch 3.33 ... Loss 0.754 ... Acc 0.000
# ... Iteration 4360 ... Epoch 3.33 ... Loss 0.678 ... Acc 1.000
# ... Iteration 4370 ... Epoch 3.34 ... Loss 0.700 ... Acc 0.000
# ... Iteration 4380 ... Epoch 3.35 ... Loss 0.676 ... Acc 1.000
# ... Iteration 4390 ... Epoch 3.36 ... Loss 0.685 ... Acc 1.000
# ... Iteration 4400 ... Epoch 3.36 ... Loss 0.688 ... Acc 1.000
# ... Iteration 4410 ... Epoch 3.37 ... Loss 0.697 ... Acc 0.000
# ... Iteration 4420 ... Epoch 3.38 ... Loss 0.673 ... Acc 1.000
# ... Iteration 4430 ... Epoch 3.39 ... Loss 0.732 ... Acc 0.000
# ... Iteration 4440 ... Epoch 3.39 ... Loss 0.725 ... Acc 0.000
# ... Iteration 4450 ... Epoch 3.40 ... Loss 0.736 ... Acc 0.000
# ... Iteration 4460 ... Epoch 3.41 ... Loss 0.649 ... Acc 1.000
# ... Iteration 4470 ... Epoch 3.42 ... Loss 0.626 ... Acc 1.000
# ... Iteration 4480 ... Epoch 3.43 ... Loss 0.807 ... Acc 0.000
# ... Iteration 4490 ... Epoch 3.43 ... Loss 0.807 ... Acc 0.000
# ... Iteration 4500 ... Epoch 3.44 ... Loss 0.611 ... Acc 1.000
# ... Iteration 4510 ... Epoch 3.45 ... Loss 0.788 ... Acc 0.000
# ... Iteration 4520 ... Epoch 3.46 ... Loss 0.780 ... Acc 0.000
# ... Iteration 4530 ... Epoch 3.46 ... Loss 0.643 ... Acc 1.000
# ... Iteration 4540 ... Epoch 3.47 ... Loss 0.642 ... Acc 1.000
# ... Iteration 4550 ... Epoch 3.48 ... Loss 0.768 ... Acc 0.000
# ... Iteration 4560 ... Epoch 3.49 ... Loss 0.777 ... Acc 0.000
# ... Iteration 4570 ... Epoch 3.49 ... Loss 0.637 ... Acc 1.000
# ... Iteration 4580 ... Epoch 3.50 ... Loss 0.666 ... Acc 1.000
# ... Iteration 4590 ... Epoch 3.51 ... Loss 0.700 ... Acc 0.000
# ... Iteration 4600 ... Epoch 3.52 ... Loss 0.673 ... Acc 1.000
# ... Iteration 4610 ... Epoch 3.52 ... Loss 0.748 ... Acc 0.000
# ... Iteration 4620 ... Epoch 3.53 ... Loss 0.752 ... Acc 0.000
# ... Iteration 4630 ... Epoch 3.54 ... Loss 0.650 ... Acc 1.000
# ... Iteration 4640 ... Epoch 3.55 ... Loss 0.635 ... Acc 1.000
# ... Iteration 4650 ... Epoch 3.56 ... Loss 0.765 ... Acc 0.000
# ... Iteration 4660 ... Epoch 3.56 ... Loss 0.759 ... Acc 0.000
# ... Iteration 4670 ... Epoch 3.57 ... Loss 0.733 ... Acc 0.000
# ... Iteration 4680 ... Epoch 3.58 ... Loss 0.658 ... Acc 1.000
# ... Iteration 4690 ... Epoch 3.59 ... Loss 0.640 ... Acc 1.000
# ... Iteration 4700 ... Epoch 3.59 ... Loss 0.633 ... Acc 1.000
# ... Iteration 4710 ... Epoch 3.60 ... Loss 0.628 ... Acc 1.000
# ... Iteration 4720 ... Epoch 3.61 ... Loss 0.777 ... Acc 0.000
# ... Iteration 4730 ... Epoch 3.62 ... Loss 0.627 ... Acc 1.000
# ... Iteration 4740 ... Epoch 3.62 ... Loss 0.755 ... Acc 0.000
# ... Iteration 4750 ... Epoch 3.63 ... Loss 0.734 ... Acc 0.000
# ... Iteration 4760 ... Epoch 3.64 ... Loss 0.726 ... Acc 0.000
# ... Iteration 4770 ... Epoch 3.65 ... Loss 0.744 ... Acc 0.000
# ... Iteration 4780 ... Epoch 3.65 ... Loss 0.618 ... Acc 1.000
# ... Iteration 4790 ... Epoch 3.66 ... Loss 0.790 ... Acc 0.000
# ... Iteration 4800 ... Epoch 3.67 ... Loss 0.780 ... Acc 0.000
# ... Iteration 4810 ... Epoch 3.68 ... Loss 0.758 ... Acc 0.000
# ... Iteration 4820 ... Epoch 3.69 ... Loss 0.723 ... Acc 0.000
# ... Iteration 4830 ... Epoch 3.69 ... Loss 0.714 ... Acc 0.000
# ... Iteration 4840 ... Epoch 3.70 ... Loss 0.750 ... Acc 0.000
# ... Iteration 4850 ... Epoch 3.71 ... Loss 0.638 ... Acc 1.000
# ... Iteration 4860 ... Epoch 3.72 ... Loss 0.740 ... Acc 0.000
# ... Iteration 4870 ... Epoch 3.72 ... Loss 0.677 ... Acc 1.000
# ... Iteration 4880 ... Epoch 3.73 ... Loss 0.706 ... Acc 0.000
# ... Iteration 4890 ... Epoch 3.74 ... Loss 0.720 ... Acc 0.000
# ... Iteration 4900 ... Epoch 3.75 ... Loss 0.743 ... Acc 0.000
# ... Iteration 4910 ... Epoch 3.75 ... Loss 0.635 ... Acc 1.000
# ... Iteration 4920 ... Epoch 3.76 ... Loss 0.759 ... Acc 0.000
# ... Iteration 4930 ... Epoch 3.77 ... Loss 0.666 ... Acc 1.000
# ... Iteration 4940 ... Epoch 3.78 ... Loss 0.672 ... Acc 1.000
# ... Iteration 4950 ... Epoch 3.78 ... Loss 0.700 ... Acc 0.000
# ... Iteration 4960 ... Epoch 3.79 ... Loss 0.745 ... Acc 0.000
# ... Iteration 4970 ... Epoch 3.80 ... Loss 0.621 ... Acc 1.000
# ... Iteration 4980 ... Epoch 3.81 ... Loss 0.597 ... Acc 1.000
# ... Iteration 4990 ... Epoch 3.81 ... Loss 0.583 ... Acc 1.000
# ... Iteration 5000 ... Epoch 3.82 ... Loss 0.844 ... Acc 0.000
# ... Iteration 5010 ... Epoch 3.83 ... Loss 0.869 ... Acc 0.000
# ... Iteration 5020 ... Epoch 3.84 ... Loss 0.912 ... Acc 0.000
# ... Iteration 5030 ... Epoch 3.85 ... Loss 0.898 ... Acc 0.000
# ... Iteration 5040 ... Epoch 3.85 ... Loss 0.887 ... Acc 0.000
# ... Iteration 5050 ... Epoch 3.86 ... Loss 0.551 ... Acc 1.000
# ... Iteration 5060 ... Epoch 3.87 ... Loss 0.824 ... Acc 0.000
# ... Iteration 5070 ... Epoch 3.88 ... Loss 0.612 ... Acc 1.000
# ... Iteration 5080 ... Epoch 3.88 ... Loss 0.750 ... Acc 0.000
# ... Iteration 5090 ... Epoch 3.89 ... Loss 0.738 ... Acc 0.000
# ... Iteration 5100 ... Epoch 3.90 ... Loss 0.740 ... Acc 0.000
# ... Iteration 5110 ... Epoch 3.91 ... Loss 0.652 ... Acc 1.000
# ... Iteration 5120 ... Epoch 3.91 ... Loss 0.740 ... Acc 0.000
# ... Iteration 5130 ... Epoch 3.92 ... Loss 0.661 ... Acc 1.000
# ... Iteration 5140 ... Epoch 3.93 ... Loss 0.667 ... Acc 1.000
# ... Iteration 5150 ... Epoch 3.94 ... Loss 0.685 ... Acc 1.000
# ... Iteration 5160 ... Epoch 3.94 ... Loss 0.702 ... Acc 0.000
# ... Iteration 5170 ... Epoch 3.95 ... Loss 0.676 ... Acc 1.000
# ... Iteration 5180 ... Epoch 3.96 ... Loss 0.736 ... Acc 0.000
# ... Iteration 5190 ... Epoch 3.97 ... Loss 0.723 ... Acc 0.000
# ... Iteration 5200 ... Epoch 3.98 ... Loss 0.681 ... Acc 1.000
# ... Iteration 5210 ... Epoch 3.98 ... Loss 0.681 ... Acc 1.000
# ... Iteration 5220 ... Epoch 3.99 ... Loss 0.720 ... Acc 0.000
# ... Iteration 5230 ... Epoch 4.00 ... Loss 0.664 ... Acc 1.000
# Epoch 3 Starting @ 2020-02-03 10:18:40
# ... Iteration 5240 ... Epoch 4.01 ... Loss 0.736 ... Acc 0.000
# ... Iteration 5250 ... Epoch 4.01 ... Loss 0.743 ... Acc 0.000
# ... Iteration 5260 ... Epoch 4.02 ... Loss 0.735 ... Acc 0.000
# ... Iteration 5270 ... Epoch 4.03 ... Loss 0.648 ... Acc 1.000
# ... Iteration 5280 ... Epoch 4.04 ... Loss 0.622 ... Acc 1.000
# ... Iteration 5290 ... Epoch 4.04 ... Loss 0.786 ... Acc 0.000
# ... Iteration 5300 ... Epoch 4.05 ... Loss 0.778 ... Acc 0.000
# ... Iteration 5310 ... Epoch 4.06 ... Loss 0.621 ... Acc 1.000
# ... Iteration 5320 ... Epoch 4.07 ... Loss 0.790 ... Acc 0.000
# ... Iteration 5330 ... Epoch 4.07 ... Loss 0.611 ... Acc 1.000
# ... Iteration 5340 ... Epoch 4.08 ... Loss 0.595 ... Acc 1.000
# ... Iteration 5350 ... Epoch 4.09 ... Loss 0.827 ... Acc 0.000
# ... Iteration 5360 ... Epoch 4.10 ... Loss 0.588 ... Acc 1.000
# ... Iteration 5370 ... Epoch 4.11 ... Loss 0.579 ... Acc 1.000
# ... Iteration 5380 ... Epoch 4.11 ... Loss 0.810 ... Acc 0.000
# ... Iteration 5390 ... Epoch 4.12 ... Loss 0.786 ... Acc 0.000
# ... Iteration 5400 ... Epoch 4.13 ... Loss 0.619 ... Acc 1.000
# ... Iteration 5410 ... Epoch 4.14 ... Loss 0.769 ... Acc 0.000
# ... Iteration 5420 ... Epoch 4.14 ... Loss 0.730 ... Acc 0.000
# ... Iteration 5430 ... Epoch 4.15 ... Loss 0.718 ... Acc 0.000
# ... Iteration 5440 ... Epoch 4.16 ... Loss 0.672 ... Acc 1.000
# ... Iteration 5450 ... Epoch 4.17 ... Loss 0.708 ... Acc 0.000
# ... Iteration 5460 ... Epoch 4.17 ... Loss 0.702 ... Acc 0.000
# ... Iteration 5470 ... Epoch 4.18 ... Loss 0.703 ... Acc 0.000
# ... Iteration 5480 ... Epoch 4.19 ... Loss 0.702 ... Acc 0.000
# ... Iteration 5490 ... Epoch 4.20 ... Loss 0.700 ... Acc 0.000
# ... Iteration 5500 ... Epoch 4.20 ... Loss 0.693 ... Acc 1.000
# ... Iteration 5510 ... Epoch 4.21 ... Loss 0.697 ... Acc 0.000
# ... Iteration 5520 ... Epoch 4.22 ... Loss 0.692 ... Acc 1.000
# ... Iteration 5530 ... Epoch 4.23 ... Loss 0.681 ... Acc 1.000
# ... Iteration 5540 ... Epoch 4.24 ... Loss 0.723 ... Acc 0.000
# ... Iteration 5550 ... Epoch 4.24 ... Loss 0.731 ... Acc 0.000
# ... Iteration 5560 ... Epoch 4.25 ... Loss 0.764 ... Acc 0.000
# ... Iteration 5570 ... Epoch 4.26 ... Loss 0.640 ... Acc 1.000
# ... Iteration 5580 ... Epoch 4.27 ... Loss 0.660 ... Acc 1.000
# ... Iteration 5590 ... Epoch 4.27 ... Loss 0.720 ... Acc 0.000
# ... Iteration 5600 ... Epoch 4.28 ... Loss 0.657 ... Acc 1.000
# ... Iteration 5610 ... Epoch 4.29 ... Loss 0.756 ... Acc 0.000
# ... Iteration 5620 ... Epoch 4.30 ... Loss 0.652 ... Acc 1.000
# ... Iteration 5630 ... Epoch 4.30 ... Loss 0.653 ... Acc 1.000
# ... Iteration 5640 ... Epoch 4.31 ... Loss 0.733 ... Acc 0.000
# ... Iteration 5650 ... Epoch 4.32 ... Loss 0.700 ... Acc 0.000
# ... Iteration 5660 ... Epoch 4.33 ... Loss 0.660 ... Acc 1.000
# ... Iteration 5670 ... Epoch 4.33 ... Loss 0.750 ... Acc 0.000
# ... Iteration 5680 ... Epoch 4.34 ... Loss 0.663 ... Acc 1.000
# ... Iteration 5690 ... Epoch 4.35 ... Loss 0.671 ... Acc 1.000
# ... Iteration 5700 ... Epoch 4.36 ... Loss 0.744 ... Acc 0.000
# ... Iteration 5710 ... Epoch 4.37 ... Loss 0.659 ... Acc 1.000
# ... Iteration 5720 ... Epoch 4.37 ... Loss 0.731 ... Acc 0.000
# ... Iteration 5730 ... Epoch 4.38 ... Loss 0.742 ... Acc 0.000
# ... Iteration 5740 ... Epoch 4.39 ... Loss 0.747 ... Acc 0.000
# ... Iteration 5750 ... Epoch 4.40 ... Loss 0.652 ... Acc 1.000
# ... Iteration 5760 ... Epoch 4.40 ... Loss 0.652 ... Acc 1.000
# ... Iteration 5770 ... Epoch 4.41 ... Loss 0.754 ... Acc 0.000
# ... Iteration 5780 ... Epoch 4.42 ... Loss 0.630 ... Acc 1.000
# ... Iteration 5790 ... Epoch 4.43 ... Loss 0.777 ... Acc 0.000
# ... Iteration 5800 ... Epoch 4.43 ... Loss 0.626 ... Acc 1.000
# ... Iteration 5810 ... Epoch 4.44 ... Loss 0.776 ... Acc 0.000
# ... Iteration 5820 ... Epoch 4.45 ... Loss 0.793 ... Acc 0.000
# ... Iteration 5830 ... Epoch 4.46 ... Loss 0.768 ... Acc 0.000
# ... Iteration 5840 ... Epoch 4.46 ... Loss 0.718 ... Acc 0.000
# ... Iteration 5850 ... Epoch 4.47 ... Loss 0.695 ... Acc 0.000
# ... Iteration 5860 ... Epoch 4.48 ... Loss 0.711 ... Acc 0.000
# ... Iteration 5870 ... Epoch 4.49 ... Loss 0.672 ... Acc 1.000
# ... Iteration 5880 ... Epoch 4.50 ... Loss 0.706 ... Acc 0.000
# ... Iteration 5890 ... Epoch 4.50 ... Loss 0.679 ... Acc 1.000
# ... Iteration 5900 ... Epoch 4.51 ... Loss 0.705 ... Acc 0.000
# ... Iteration 5910 ... Epoch 4.52 ... Loss 0.676 ... Acc 1.000
# ... Iteration 5920 ... Epoch 4.53 ... Loss 0.653 ... Acc 1.000
# ... Iteration 5930 ... Epoch 4.53 ... Loss 0.728 ... Acc 0.000
# ... Iteration 5940 ... Epoch 4.54 ... Loss 0.686 ... Acc 1.000
# ... Iteration 5950 ... Epoch 4.55 ... Loss 0.694 ... Acc 0.000
# ... Iteration 5960 ... Epoch 4.56 ... Loss 0.662 ... Acc 1.000
# ... Iteration 5970 ... Epoch 4.56 ... Loss 0.769 ... Acc 0.000
# ... Iteration 5980 ... Epoch 4.57 ... Loss 0.782 ... Acc 0.000
# ... Iteration 5990 ... Epoch 4.58 ... Loss 0.640 ... Acc 1.000
# ... Iteration 6000 ... Epoch 4.59 ... Loss 0.626 ... Acc 1.000
# ... Iteration 6010 ... Epoch 4.59 ... Loss 0.587 ... Acc 1.000
# ... Iteration 6020 ... Epoch 4.60 ... Loss 0.815 ... Acc 0.000
# ... Iteration 6030 ... Epoch 4.61 ... Loss 0.800 ... Acc 0.000
# ... Iteration 6040 ... Epoch 4.62 ... Loss 0.785 ... Acc 0.000
# ... Iteration 6050 ... Epoch 4.63 ... Loss 0.757 ... Acc 0.000
# ... Iteration 6060 ... Epoch 4.63 ... Loss 0.665 ... Acc 1.000
# ... Iteration 6070 ... Epoch 4.64 ... Loss 0.713 ... Acc 0.000
# ... Iteration 6080 ... Epoch 4.65 ... Loss 0.677 ... Acc 1.000
# ... Iteration 6090 ... Epoch 4.66 ... Loss 0.734 ... Acc 0.000
# ... Iteration 6100 ... Epoch 4.66 ... Loss 0.622 ... Acc 1.000
# ... Iteration 6110 ... Epoch 4.67 ... Loss 0.800 ... Acc 0.000
# ... Iteration 6120 ... Epoch 4.68 ... Loss 0.773 ... Acc 0.000
# ... Iteration 6130 ... Epoch 4.69 ... Loss 0.754 ... Acc 0.000
# ... Iteration 6140 ... Epoch 4.69 ... Loss 0.732 ... Acc 0.000
# ... Iteration 6150 ... Epoch 4.70 ... Loss 0.717 ... Acc 0.000
# ... Iteration 6160 ... Epoch 4.71 ... Loss 0.665 ... Acc 1.000
# ... Iteration 6170 ... Epoch 4.72 ... Loss 0.738 ... Acc 0.000
# ... Iteration 6180 ... Epoch 4.72 ... Loss 0.725 ... Acc 0.000
# ... Iteration 6190 ... Epoch 4.73 ... Loss 0.682 ... Acc 1.000
# ... Iteration 6200 ... Epoch 4.74 ... Loss 0.755 ... Acc 0.000
# ... Iteration 6210 ... Epoch 4.75 ... Loss 0.784 ... Acc 0.000
# ... Iteration 6220 ... Epoch 4.76 ... Loss 0.763 ... Acc 0.000
# ... Iteration 6230 ... Epoch 4.76 ... Loss 0.741 ... Acc 0.000
# ... Iteration 6240 ... Epoch 4.77 ... Loss 0.757 ... Acc 0.000
# ... Iteration 6250 ... Epoch 4.78 ... Loss 0.772 ... Acc 0.000
# ... Iteration 6260 ... Epoch 4.79 ... Loss 0.601 ... Acc 1.000
# ... Iteration 6270 ... Epoch 4.79 ... Loss 0.593 ... Acc 1.000
# ... Iteration 6280 ... Epoch 4.80 ... Loss 0.807 ... Acc 0.000
# ... Iteration 6290 ... Epoch 4.81 ... Loss 0.761 ... Acc 0.000
# ... Iteration 6300 ... Epoch 4.82 ... Loss 0.742 ... Acc 0.000
# ... Iteration 6310 ... Epoch 4.82 ... Loss 0.649 ... Acc 1.000
# ... Iteration 6320 ... Epoch 4.83 ... Loss 0.756 ... Acc 0.000
# ... Iteration 6330 ... Epoch 4.84 ... Loss 0.636 ... Acc 1.000
# ... Iteration 6340 ... Epoch 4.85 ... Loss 0.759 ... Acc 0.000
# ... Iteration 6350 ... Epoch 4.85 ... Loss 0.629 ... Acc 1.000
# ... Iteration 6360 ... Epoch 4.86 ... Loss 0.627 ... Acc 1.000
# ... Iteration 6370 ... Epoch 4.87 ... Loss 0.788 ... Acc 0.000
# ... Iteration 6380 ... Epoch 4.88 ... Loss 0.777 ... Acc 0.000
# ... Iteration 6390 ... Epoch 4.89 ... Loss 0.634 ... Acc 1.000
# ... Iteration 6400 ... Epoch 4.89 ... Loss 0.734 ... Acc 0.000
# ... Iteration 6410 ... Epoch 4.90 ... Loss 0.661 ... Acc 1.000
# ... Iteration 6420 ... Epoch 4.91 ... Loss 0.635 ... Acc 1.000
# ... Iteration 6430 ... Epoch 4.92 ... Loss 0.621 ... Acc 1.000
# ... Iteration 6440 ... Epoch 4.92 ... Loss 0.616 ... Acc 1.000
# ... Iteration 6450 ... Epoch 4.93 ... Loss 0.784 ... Acc 0.000
# ... Iteration 6460 ... Epoch 4.94 ... Loss 0.804 ... Acc 0.000
# ... Iteration 6470 ... Epoch 4.95 ... Loss 0.803 ... Acc 0.000
# ... Iteration 6480 ... Epoch 4.95 ... Loss 0.602 ... Acc 1.000
# ... Iteration 6490 ... Epoch 4.96 ... Loss 0.588 ... Acc 1.000
# ... Iteration 6500 ... Epoch 4.97 ... Loss 0.586 ... Acc 1.000
# ... Iteration 6510 ... Epoch 4.98 ... Loss 0.843 ... Acc 0.000
# ... Iteration 6520 ... Epoch 4.98 ... Loss 0.577 ... Acc 1.000
# ... Iteration 6530 ... Epoch 4.99 ... Loss 0.800 ... Acc 0.000
# ... Iteration 6540 ... Epoch 5.00 ... Loss 0.610 ... Acc 1.000
# Epoch 5 Starting @ 2020-02-03 10:18:56
# ... Iteration 6550 ... Epoch 5.01 ... Loss 0.764 ... Acc 0.000
# ... Iteration 6560 ... Epoch 5.02 ... Loss 0.669 ... Acc 1.000
# ... Iteration 6570 ... Epoch 5.02 ... Loss 0.699 ... Acc 0.000
# ... Iteration 6580 ... Epoch 5.03 ... Loss 0.702 ... Acc 0.000
# ... Iteration 6590 ... Epoch 5.04 ... Loss 0.662 ... Acc 1.000
# ... Iteration 6600 ... Epoch 5.05 ... Loss 0.737 ... Acc 0.000
# ... Iteration 6610 ... Epoch 5.05 ... Loss 0.695 ... Acc 0.000
# ... Iteration 6620 ... Epoch 5.06 ... Loss 0.643 ... Acc 1.000
# ... Iteration 6630 ... Epoch 5.07 ... Loss 0.762 ... Acc 0.000
# ... Iteration 6640 ... Epoch 5.08 ... Loss 0.753 ... Acc 0.000
# ... Iteration 6650 ... Epoch 5.08 ... Loss 0.760 ... Acc 0.000
# ... Iteration 6660 ... Epoch 5.09 ... Loss 0.748 ... Acc 0.000
# ... Iteration 6670 ... Epoch 5.10 ... Loss 0.668 ... Acc 1.000
# ... Iteration 6680 ... Epoch 5.11 ... Loss 0.684 ... Acc 1.000
# ... Iteration 6690 ... Epoch 5.11 ... Loss 0.719 ... Acc 0.000
# ... Iteration 6700 ... Epoch 5.12 ... Loss 0.697 ... Acc 0.000
# ... Iteration 6710 ... Epoch 5.13 ... Loss 0.697 ... Acc 0.000
# ... Iteration 6720 ... Epoch 5.14 ... Loss 0.667 ... Acc 1.000
# ... Iteration 6730 ... Epoch 5.15 ... Loss 0.738 ... Acc 0.000
# ... Iteration 6740 ... Epoch 5.15 ... Loss 0.718 ... Acc 0.000
# ... Iteration 6750 ... Epoch 5.16 ... Loss 0.726 ... Acc 0.000
# ... Iteration 6760 ... Epoch 5.17 ... Loss 0.735 ... Acc 0.000
# ... Iteration 6770 ... Epoch 5.18 ... Loss 0.722 ... Acc 0.000
# ... Iteration 6780 ... Epoch 5.18 ... Loss 0.690 ... Acc 1.000
# ... Iteration 6790 ... Epoch 5.19 ... Loss 0.722 ... Acc 0.000
# ... Iteration 6800 ... Epoch 5.20 ... Loss 0.682 ... Acc 1.000
# ... Iteration 6810 ... Epoch 5.21 ... Loss 0.692 ... Acc 1.000
# ... Iteration 6820 ... Epoch 5.21 ... Loss 0.693 ... Acc 1.000
# ... Iteration 6830 ... Epoch 5.22 ... Loss 0.697 ... Acc 0.000
# ... Iteration 6840 ... Epoch 5.23 ... Loss 0.721 ... Acc 0.000
# ... Iteration 6850 ... Epoch 5.24 ... Loss 0.655 ... Acc 1.000
# ... Iteration 6860 ... Epoch 5.24 ... Loss 0.644 ... Acc 1.000
# ... Iteration 6870 ... Epoch 5.25 ... Loss 0.623 ... Acc 1.000
# ... Iteration 6880 ... Epoch 5.26 ... Loss 0.795 ... Acc 0.000
# ... Iteration 6890 ... Epoch 5.27 ... Loss 0.786 ... Acc 0.000
# ... Iteration 6900 ... Epoch 5.28 ... Loss 0.630 ... Acc 1.000
# ... Iteration 6910 ... Epoch 5.28 ... Loss 0.744 ... Acc 0.000
# ... Iteration 6920 ... Epoch 5.29 ... Loss 0.703 ... Acc 0.000
# ... Iteration 6930 ... Epoch 5.30 ... Loss 0.741 ... Acc 0.000
# ... Iteration 6940 ... Epoch 5.31 ... Loss 0.635 ... Acc 1.000
# ... Iteration 6950 ... Epoch 5.31 ... Loss 0.634 ... Acc 1.000
# ... Iteration 6960 ... Epoch 5.32 ... Loss 0.762 ... Acc 0.000
# ... Iteration 6970 ... Epoch 5.33 ... Loss 0.770 ... Acc 0.000
# ... Iteration 6980 ... Epoch 5.34 ... Loss 0.626 ... Acc 1.000
# ... Iteration 6990 ... Epoch 5.34 ... Loss 0.627 ... Acc 1.000
# ... Iteration 7000 ... Epoch 5.35 ... Loss 0.649 ... Acc 1.000
# ... Iteration 7010 ... Epoch 5.36 ... Loss 0.731 ... Acc 0.000
# ... Iteration 7020 ... Epoch 5.37 ... Loss 0.683 ... Acc 1.000
# ... Iteration 7030 ... Epoch 5.37 ... Loss 0.695 ... Acc 0.000
# ... Iteration 7040 ... Epoch 5.38 ... Loss 0.677 ... Acc 1.000
# ... Iteration 7050 ... Epoch 5.39 ... Loss 0.727 ... Acc 0.000
# ... Iteration 7060 ... Epoch 5.40 ... Loss 0.668 ... Acc 1.000
# ... Iteration 7070 ... Epoch 5.41 ... Loss 0.701 ... Acc 0.000
# ... Iteration 7080 ... Epoch 5.41 ... Loss 0.688 ... Acc 1.000
# ... Iteration 7090 ... Epoch 5.42 ... Loss 0.691 ... Acc 1.000
# ... Iteration 7100 ... Epoch 5.43 ... Loss 0.712 ... Acc 0.000
# ... Iteration 7110 ... Epoch 5.44 ... Loss 0.729 ... Acc 0.000
# ... Iteration 7120 ... Epoch 5.44 ... Loss 0.733 ... Acc 0.000
# ... Iteration 7130 ... Epoch 5.45 ... Loss 0.719 ... Acc 0.000
# ... Iteration 7140 ... Epoch 5.46 ... Loss 0.684 ... Acc 1.000
# ... Iteration 7150 ... Epoch 5.47 ... Loss 0.697 ... Acc 0.000
# ... Iteration 7160 ... Epoch 5.47 ... Loss 0.709 ... Acc 0.000
# ... Iteration 7170 ... Epoch 5.48 ... Loss 0.710 ... Acc 0.000
# ... Iteration 7180 ... Epoch 5.49 ... Loss 0.679 ... Acc 1.000
# ... Iteration 7190 ... Epoch 5.50 ... Loss 0.657 ... Acc 1.000
# ... Iteration 7200 ... Epoch 5.50 ... Loss 0.649 ... Acc 1.000
# ... Iteration 7210 ... Epoch 5.51 ... Loss 0.652 ... Acc 1.000
# ... Iteration 7220 ... Epoch 5.52 ... Loss 0.750 ... Acc 0.000
# ... Iteration 7230 ... Epoch 5.53 ... Loss 0.758 ... Acc 0.000
# ... Iteration 7240 ... Epoch 5.54 ... Loss 0.655 ... Acc 1.000
# ... Iteration 7250 ... Epoch 5.54 ... Loss 0.689 ... Acc 1.000
# ... Iteration 7260 ... Epoch 5.55 ... Loss 0.686 ... Acc 1.000
# ... Iteration 7270 ... Epoch 5.56 ... Loss 0.697 ... Acc 0.000
# ... Iteration 7280 ... Epoch 5.57 ... Loss 0.682 ... Acc 1.000
# ... Iteration 7290 ... Epoch 5.57 ... Loss 0.719 ... Acc 0.000
# ... Iteration 7300 ... Epoch 5.58 ... Loss 0.718 ... Acc 0.000
# ... Iteration 7310 ... Epoch 5.59 ... Loss 0.679 ... Acc 1.000
# ... Iteration 7320 ... Epoch 5.60 ... Loss 0.692 ... Acc 1.000
# ... Iteration 7330 ... Epoch 5.60 ... Loss 0.660 ... Acc 1.000
# ... Iteration 7340 ... Epoch 5.61 ... Loss 0.645 ... Acc 1.000
# ... Iteration 7350 ... Epoch 5.62 ... Loss 0.630 ... Acc 1.000
# ... Iteration 7360 ... Epoch 5.63 ... Loss 0.804 ... Acc 0.000
# ... Iteration 7370 ... Epoch 5.63 ... Loss 0.805 ... Acc 0.000
# ... Iteration 7380 ... Epoch 5.64 ... Loss 0.790 ... Acc 0.000
# ... Iteration 7390 ... Epoch 5.65 ... Loss 0.604 ... Acc 1.000
# ... Iteration 7400 ... Epoch 5.66 ... Loss 0.008 ... Acc 1.000
# ... Iteration 7410 ... Epoch 5.67 ... Loss 0.646 ... Acc 1.000
# ... Iteration 7420 ... Epoch 5.67 ... Loss 0.659 ... Acc 1.000
# ... Iteration 7430 ... Epoch 5.68 ... Loss 0.655 ... Acc 1.000
# ... Iteration 7440 ... Epoch 5.69 ... Loss 0.756 ... Acc 0.000
# ... Iteration 7450 ... Epoch 5.70 ... Loss 0.621 ... Acc 1.000
# ... Iteration 7460 ... Epoch 5.70 ... Loss 0.804 ... Acc 0.000
# ... Iteration 7470 ... Epoch 5.71 ... Loss 0.586 ... Acc 1.000
# ... Iteration 7480 ... Epoch 5.72 ... Loss 0.785 ... Acc 0.000
# ... Iteration 7490 ... Epoch 5.73 ... Loss 0.612 ... Acc 1.000
# ... Iteration 7500 ... Epoch 5.73 ... Loss 0.799 ... Acc 0.000
# ... Iteration 7510 ... Epoch 5.74 ... Loss 0.786 ... Acc 0.000
# ... Iteration 7520 ... Epoch 5.75 ... Loss 0.610 ... Acc 1.000
# ... Iteration 7530 ... Epoch 5.76 ... Loss 0.580 ... Acc 1.000
# ... Iteration 7540 ... Epoch 5.76 ... Loss 0.577 ... Acc 1.000
# ... Iteration 7550 ... Epoch 5.77 ... Loss 0.580 ... Acc 1.000
# ... Iteration 7560 ... Epoch 5.78 ... Loss 0.833 ... Acc 0.000
# ... Iteration 7570 ... Epoch 5.79 ... Loss 0.805 ... Acc 0.000
# ... Iteration 7580 ... Epoch 5.80 ... Loss 0.791 ... Acc 0.000
# ... Iteration 7590 ... Epoch 5.80 ... Loss 0.634 ... Acc 1.000
# ...
# ... Iteration 10600 ... Epoch 8.10 ... Loss 0.617 ... Acc 1.000
# ... Iteration 10610 ... Epoch 8.11 ... Loss 0.624 ... Acc 1.000
# ... Iteration 10620 ... Epoch 8.12 ... Loss 0.769 ... Acc 0.000
# ... Iteration 10630 ... Epoch 8.13 ... Loss 0.776 ... Acc 0.000
# ... Iteration 10640 ... Epoch 8.13 ... Loss 0.639 ... Acc 1.000
# ... Iteration 10650 ... Epoch 8.14 ... Loss 0.653 ... Acc 1.000
# ... Iteration 10660 ... Epoch 8.15 ... Loss 0.654 ... Acc 1.000
# ... Iteration 10670 ... Epoch 8.16 ... Loss 0.727 ... Acc 0.000
# ... Iteration 10680 ... Epoch 8.17 ... Loss 0.658 ... Acc 1.000
# ... Iteration 10690 ... Epoch 8.17 ... Loss 0.741 ... Acc 0.000
# ... Iteration 10700 ... Epoch 8.18 ... Loss 0.637 ... Acc 1.000
# ... Iteration 10710 ... Epoch 8.19 ... Loss 0.620 ... Acc 1.000
# ... Iteration 10720 ... Epoch 8.20 ... Loss 0.622 ... Acc 1.000
# ... Iteration 10730 ... Epoch 8.20 ... Loss 0.614 ... Acc 1.000
# ... Iteration 10740 ... Epoch 8.21 ... Loss 0.776 ... Acc 0.000
# ... Iteration 10750 ... Epoch 8.22 ... Loss 0.758 ... Acc 0.000
# ... Iteration 10760 ... Epoch 8.23 ... Loss 0.744 ... Acc 0.000
# ... Iteration 10770 ... Epoch 8.23 ... Loss 0.742 ... Acc 0.000
# ... Iteration 10780 ... Epoch 8.24 ... Loss 0.654 ... Acc 1.000
# ... Iteration 10790 ... Epoch 8.25 ... Loss 0.635 ... Acc 1.000
# ... Iteration 10800 ... Epoch 8.26 ... Loss 0.752 ... Acc 0.000
# ... Iteration 10810 ... Epoch 8.26 ... Loss 0.644 ... Acc 1.000
# ... Iteration 10820 ... Epoch 8.27 ... Loss 0.772 ... Acc 0.000
# ... Iteration 10830 ... Epoch 8.28 ... Loss 0.798 ... Acc 0.000
# ... Iteration 10840 ... Epoch 8.29 ... Loss 0.774 ... Acc 0.000
# ... Iteration 10850 ... Epoch 8.30 ... Loss 0.617 ... Acc 1.000
# ... Iteration 10860 ... Epoch 8.30 ... Loss 0.596 ... Acc 1.000
# ... Iteration 10870 ... Epoch 8.31 ... Loss 0.829 ... Acc 0.000
# ... Iteration 10880 ... Epoch 8.32 ... Loss 0.567 ... Acc 1.000
# ... Iteration 10890 ... Epoch 8.33 ... Loss 0.851 ... Acc 0.000
# ... Iteration 10900 ... Epoch 8.33 ... Loss 0.851 ... Acc 0.000
# ... Iteration 10910 ... Epoch 8.34 ... Loss 0.797 ... Acc 0.000
# ... Iteration 10920 ... Epoch 8.35 ... Loss 0.631 ... Acc 1.000
# ... Iteration 10930 ... Epoch 8.36 ... Loss 0.724 ... Acc 0.000
# ... Iteration 10940 ... Epoch 8.36 ... Loss 0.659 ... Acc 1.000
# ... Iteration 10950 ... Epoch 8.37 ... Loss 0.762 ... Acc 0.000
# ... Iteration 10960 ... Epoch 8.38 ... Loss 0.794 ... Acc 0.000
# ... Iteration 10970 ... Epoch 8.39 ... Loss 0.802 ... Acc 0.000
# ... Iteration 10980 ... Epoch 8.39 ... Loss 0.771 ... Acc 0.000
# ... Iteration 10990 ... Epoch 8.40 ... Loss 0.728 ... Acc 0.000
# ... Iteration 11000 ... Epoch 8.41 ... Loss 0.700 ... Acc 0.000
# ... Iteration 11010 ... Epoch 8.42 ... Loss 0.676 ... Acc 1.000
# ... Iteration 11020 ... Epoch 8.43 ... Loss 0.674 ... Acc 1.000
# ... Iteration 11030 ... Epoch 8.43 ... Loss 0.644 ... Acc 1.000
# ... Iteration 11040 ... Epoch 8.44 ... Loss 0.789 ... Acc 0.000
# ... Iteration 11050 ... Epoch 8.45 ... Loss 0.811 ... Acc 0.000
# ... Iteration 11060 ... Epoch 8.46 ... Loss 0.586 ... Acc 1.000
# ... Iteration 11070 ... Epoch 8.46 ... Loss 0.574 ... Acc 1.000
# ... Iteration 11080 ... Epoch 8.47 ... Loss 0.838 ... Acc 0.000
# ... Iteration 11090 ... Epoch 8.48 ... Loss 0.579 ... Acc 1.000
# ... Iteration 11100 ... Epoch 8.49 ... Loss 0.790 ... Acc 0.000
# ... Iteration 11110 ... Epoch 8.49 ... Loss 0.795 ... Acc 0.000
# ... Iteration 11120 ... Epoch 8.50 ... Loss 0.610 ... Acc 1.000
# ... Iteration 11130 ... Epoch 8.51 ... Loss 0.611 ... Acc 1.000
# ... Iteration 11140 ... Epoch 8.52 ... Loss 0.770 ... Acc 0.000
# ... Iteration 11150 ... Epoch 8.52 ... Loss 0.624 ... Acc 1.000
# ... Iteration 11160 ... Epoch 8.53 ... Loss 0.755 ... Acc 0.000
# ... Iteration 11170 ... Epoch 8.54 ... Loss 0.639 ... Acc 1.000
# ... Iteration 11180 ... Epoch 8.55 ... Loss 0.753 ... Acc 0.000
# ... Iteration 11190 ... Epoch 8.56 ... Loss 0.656 ... Acc 1.000
# ... Iteration 11200 ... Epoch 8.56 ... Loss 0.728 ... Acc 0.000
# ... Iteration 11210 ... Epoch 8.57 ... Loss 0.682 ... Acc 1.000
# ... Iteration 11220 ... Epoch 8.58 ... Loss 0.702 ... Acc 0.000
# ... Iteration 11230 ... Epoch 8.59 ... Loss 0.697 ... Acc 0.000
# ... Iteration 11240 ... Epoch 8.59 ... Loss 0.694 ... Acc 0.000
# ... Iteration 11250 ... Epoch 8.60 ... Loss 0.705 ... Acc 0.000
# ... Iteration 11260 ... Epoch 8.61 ... Loss 0.698 ... Acc 0.000
# ... Iteration 11270 ... Epoch 8.62 ... Loss 0.697 ... Acc 0.000
# ... Iteration 11280 ... Epoch 8.62 ... Loss 0.690 ... Acc 1.000
# ... Iteration 11290 ... Epoch 8.63 ... Loss 0.735 ... Acc 0.000
# ... Iteration 11300 ... Epoch 8.64 ... Loss 0.737 ... Acc 0.000
# ... Iteration 11310 ... Epoch 8.65 ... Loss 0.643 ... Acc 1.000
# ... Iteration 11320 ... Epoch 8.65 ... Loss 0.622 ... Acc 1.000
# ... Iteration 11330 ... Epoch 8.66 ... Loss 0.607 ... Acc 1.000
# ... Iteration 11340 ... Epoch 8.67 ... Loss 0.620 ... Acc 1.000
# ... Iteration 11350 ... Epoch 8.68 ... Loss 0.770 ... Acc 0.000
# ... Iteration 11360 ... Epoch 8.69 ... Loss 0.627 ... Acc 1.000
# ... Iteration 11370 ... Epoch 8.69 ... Loss 0.800 ... Acc 0.000
# ... Iteration 11380 ... Epoch 8.70 ... Loss 0.812 ... Acc 0.000
# ... Iteration 11390 ... Epoch 8.71 ... Loss 0.800 ... Acc 0.000
# ... Iteration 11400 ... Epoch 8.72 ... Loss 0.617 ... Acc 1.000
# ... Iteration 11410 ... Epoch 8.72 ... Loss 0.800 ... Acc 0.000
# ... Iteration 11420 ... Epoch 8.73 ... Loss 0.796 ... Acc 0.000
# ... Iteration 11430 ... Epoch 8.74 ... Loss 0.625 ... Acc 1.000
# ... Iteration 11440 ... Epoch 8.75 ... Loss 0.759 ... Acc 0.000
# ... Iteration 11450 ... Epoch 8.75 ... Loss 0.732 ... Acc 0.000
# ... Iteration 11460 ... Epoch 8.76 ... Loss 0.730 ... Acc 0.000
# ... Iteration 11470 ... Epoch 8.77 ... Loss 0.753 ... Acc 0.000
# ... Iteration 11480 ... Epoch 8.78 ... Loss 0.785 ... Acc 0.000
# ... Iteration 11490 ... Epoch 8.78 ... Loss 0.744 ... Acc 0.000
# ... Iteration 11500 ... Epoch 8.79 ... Loss 0.701 ... Acc 0.000
# ... Iteration 11510 ... Epoch 8.80 ... Loss 0.724 ... Acc 0.000
# ... Iteration 11520 ... Epoch 8.81 ... Loss 0.659 ... Acc 1.000
# ... Iteration 11530 ... Epoch 8.81 ... Loss 0.752 ... Acc 0.000
# ... Iteration 11540 ... Epoch 8.82 ... Loss 0.631 ... Acc 1.000
# ... Iteration 11550 ... Epoch 8.83 ... Loss 0.632 ... Acc 1.000
# ... Iteration 11560 ... Epoch 8.84 ... Loss 0.760 ... Acc 0.000
# ... Iteration 11570 ... Epoch 8.85 ... Loss 0.734 ... Acc 0.000
# ... Iteration 11580 ... Epoch 8.85 ... Loss 0.675 ... Acc 1.000
# ... Iteration 11590 ... Epoch 8.86 ... Loss 0.713 ... Acc 0.000
# ... Iteration 11600 ... Epoch 8.87 ... Loss 0.661 ... Acc 1.000
# ... Iteration 11610 ... Epoch 8.88 ... Loss 0.760 ... Acc 0.000
# ... Iteration 11620 ... Epoch 8.88 ... Loss 0.632 ... Acc 1.000
# ... Iteration 11630 ... Epoch 8.89 ... Loss 0.768 ... Acc 0.000
# ... Iteration 11640 ... Epoch 8.90 ... Loss 0.641 ... Acc 1.000
# ... Iteration 11650 ... Epoch 8.91 ... Loss 0.632 ... Acc 1.000
# ... Iteration 11660 ... Epoch 8.91 ... Loss 0.746 ... Acc 0.000
# ... Iteration 11670 ... Epoch 8.92 ... Loss 0.709 ... Acc 0.000
# ... Iteration 11680 ... Epoch 8.93 ... Loss 0.696 ... Acc 0.000
# ... Iteration 11690 ... Epoch 8.94 ... Loss 0.677 ... Acc 1.000
# ... Iteration 11700 ... Epoch 8.94 ... Loss 0.696 ... Acc 0.000
# ... Iteration 11710 ... Epoch 8.95 ... Loss 0.673 ... Acc 1.000
# ... Iteration 11720 ... Epoch 8.96 ... Loss 0.744 ... Acc 0.000
# ... Iteration 11730 ... Epoch 8.97 ... Loss 0.636 ... Acc 1.000
# ... Iteration 11740 ... Epoch 8.98 ... Loss 0.786 ... Acc 0.000
# ... Iteration 11750 ... Epoch 8.98 ... Loss 0.790 ... Acc 0.000
# ... Iteration 11760 ... Epoch 8.99 ... Loss 0.774 ... Acc 0.000
# ... Iteration 11770 ... Epoch 9.00 ... Loss 0.745 ... Acc 0.000
# Epoch 9 Starting @ 2020-02-03 10:19:57
# ... Iteration 11780 ... Epoch 9.01 ... Loss 0.753 ... Acc 0.000
# ... Iteration 11790 ... Epoch 9.01 ... Loss 0.609 ... Acc 1.000
# ... Iteration 11800 ... Epoch 9.02 ... Loss 0.571 ... Acc 1.000
# ... Iteration 11810 ... Epoch 9.03 ... Loss 0.871 ... Acc 0.000
# ... Iteration 11820 ... Epoch 9.04 ... Loss 0.877 ... Acc 0.000
# ... Iteration 11830 ... Epoch 9.04 ... Loss 0.536 ... Acc 1.000
# ... Iteration 11840 ... Epoch 9.05 ... Loss 0.535 ... Acc 1.000
# ... Iteration 11850 ... Epoch 9.06 ... Loss 0.873 ... Acc 0.000
# ... Iteration 11860 ... Epoch 9.07 ... Loss 0.825 ... Acc 0.000
# ... Iteration 11870 ... Epoch 9.07 ... Loss 0.775 ... Acc 0.000
# ... Iteration 11880 ... Epoch 9.08 ... Loss 0.715 ... Acc 0.000
# ... Iteration 11890 ... Epoch 9.09 ... Loss 0.726 ... Acc 0.000
# ... Iteration 11900 ... Epoch 9.10 ... Loss 0.640 ... Acc 1.000
# ... Iteration 11910 ... Epoch 9.11 ... Loss 0.595 ... Acc 1.000
# ... Iteration 11920 ... Epoch 9.11 ... Loss 0.831 ... Acc 0.000
# ... Iteration 11930 ... Epoch 9.12 ... Loss 0.830 ... Acc 0.000
# ... Iteration 11940 ... Epoch 9.13 ... Loss 0.812 ... Acc 0.000
# ... Iteration 11950 ... Epoch 9.14 ... Loss 0.775 ... Acc 0.000
# ... Iteration 11960 ... Epoch 9.14 ... Loss 0.761 ... Acc 0.000
# ... Iteration 11970 ... Epoch 9.15 ... Loss 0.656 ... Acc 1.000
# ... Iteration 11980 ... Epoch 9.16 ... Loss 0.673 ... Acc 1.000
# ... Iteration 11990 ... Epoch 9.17 ... Loss 0.686 ... Acc 1.000
# ... Iteration 12000 ... Epoch 9.17 ... Loss 0.694 ... Acc 0.000
# ... Iteration 12010 ... Epoch 9.18 ... Loss 0.678 ... Acc 1.000
# ... Iteration 12020 ... Epoch 9.19 ... Loss 0.739 ... Acc 0.000
# ... Iteration 12030 ... Epoch 9.20 ... Loss 0.727 ... Acc 0.000
# ... Iteration 12040 ... Epoch 9.20 ... Loss 0.665 ... Acc 1.000
# ... Iteration 12050 ... Epoch 9.21 ... Loss 0.671 ... Acc 1.000
# ... Iteration 12060 ... Epoch 9.22 ... Loss 0.642 ... Acc 1.000
# ... Iteration 12070 ... Epoch 9.23 ... Loss 0.749 ... Acc 0.000
# ... Iteration 12080 ... Epoch 9.24 ... Loss 0.666 ... Acc 1.000
# ... Iteration 12090 ... Epoch 9.24 ... Loss 0.685 ... Acc 1.000
# ... Iteration 12100 ... Epoch 9.25 ... Loss 0.698 ... Acc 0.000
# ... Iteration 12110 ... Epoch 9.26 ... Loss 0.684 ... Acc 1.000
# ... Iteration 12120 ... Epoch 9.27 ... Loss 0.664 ... Acc 1.000
# ... Iteration 12130 ... Epoch 9.27 ... Loss 0.730 ... Acc 0.000
# ... Iteration 12140 ... Epoch 9.28 ... Loss 0.692 ... Acc 1.000
# ... Iteration 12150 ... Epoch 9.29 ... Loss 0.749 ... Acc 0.000
# ... Iteration 12160 ... Epoch 9.30 ... Loss 0.789 ... Acc 0.000
# ... Iteration 12170 ... Epoch 9.30 ... Loss 0.794 ... Acc 0.000
# ... Iteration 12180 ... Epoch 9.31 ... Loss 0.618 ... Acc 1.000
# ... Iteration 12190 ... Epoch 9.32 ... Loss 0.762 ... Acc 0.000
# ... Iteration 12200 ... Epoch 9.33 ... Loss 0.734 ... Acc 0.000
# ... Iteration 12210 ... Epoch 9.33 ... Loss 0.655 ... Acc 1.000
# ... Iteration 12220 ... Epoch 9.34 ... Loss 0.766 ... Acc 0.000
# ... Iteration 12230 ... Epoch 9.35 ... Loss 0.611 ... Acc 1.000
# ... Iteration 12240 ... Epoch 9.36 ... Loss 0.597 ... Acc 1.000
# ... Iteration 12250 ... Epoch 9.37 ... Loss 0.826 ... Acc 0.000
# ... Iteration 12260 ... Epoch 9.37 ... Loss 0.819 ... Acc 0.000
# ... Iteration 12270 ... Epoch 9.38 ... Loss 0.596 ... Acc 1.000
# ... Iteration 12280 ... Epoch 9.39 ... Loss 0.610 ... Acc 1.000
# ... Iteration 12290 ... Epoch 9.40 ... Loss 0.651 ... Acc 1.000
# ... Iteration 12300 ... Epoch 9.40 ... Loss 0.688 ... Acc 1.000
# ... Iteration 12310 ... Epoch 9.41 ... Loss 0.666 ... Acc 1.000
# ... Iteration 12320 ... Epoch 9.42 ... Loss 0.731 ... Acc 0.000
# ... Iteration 12330 ... Epoch 9.43 ... Loss 0.686 ... Acc 1.000
# ... Iteration 12340 ... Epoch 9.43 ... Loss 0.750 ... Acc 0.000
# ... Iteration 12350 ... Epoch 9.44 ... Loss 0.771 ... Acc 0.000
# ... Iteration 12360 ... Epoch 9.45 ... Loss 0.618 ... Acc 1.000
# ... Iteration 12370 ... Epoch 9.46 ... Loss 0.595 ... Acc 1.000
# ... Iteration 12380 ... Epoch 9.46 ... Loss 0.573 ... Acc 1.000
# ... Iteration 12390 ... Epoch 9.47 ... Loss 0.825 ... Acc 0.000
# ... Iteration 12400 ... Epoch 9.48 ... Loss 0.612 ... Acc 1.000
# ... Iteration 12410 ... Epoch 9.49 ... Loss 0.623 ... Acc 1.000
# ... Iteration 12420 ... Epoch 9.50 ... Loss 0.782 ... Acc 0.000
# ... Iteration 12430 ... Epoch 9.50 ... Loss 0.782 ... Acc 0.000
# ... Iteration 12440 ... Epoch 9.51 ... Loss 0.793 ... Acc 0.000
# ... Iteration 12450 ... Epoch 9.52 ... Loss 0.627 ... Acc 1.000
# ... Iteration 12460 ... Epoch 9.53 ... Loss 0.756 ... Acc 0.000
# ... Iteration 12470 ... Epoch 9.53 ... Loss 0.637 ... Acc 1.000
# ... Iteration 12480 ... Epoch 9.54 ... Loss 0.781 ... Acc 0.000
# ... Iteration 12490 ... Epoch 9.55 ... Loss 0.792 ... Acc 0.000
# ... Iteration 12500 ... Epoch 9.56 ... Loss 0.774 ... Acc 0.000
# ... Iteration 12510 ... Epoch 9.56 ... Loss 0.625 ... Acc 1.000
# ... Iteration 12520 ... Epoch 9.57 ... Loss 0.769 ... Acc 0.000
# ... Iteration 12530 ... Epoch 9.58 ... Loss 0.617 ... Acc 1.000
# ... Iteration 12540 ... Epoch 9.59 ... Loss 0.593 ... Acc 1.000
# ... Iteration 12550 ... Epoch 9.59 ... Loss 0.602 ... Acc 1.000
# ... Iteration 12560 ... Epoch 9.60 ... Loss 0.588 ... Acc 1.000
# ... Iteration 12570 ... Epoch 9.61 ... Loss 0.812 ... Acc 0.000
# ... Iteration 12580 ... Epoch 9.62 ... Loss 0.776 ... Acc 0.000
# ... Iteration 12590 ... Epoch 9.63 ... Loss 0.634 ... Acc 1.000
# ... Iteration 12600 ... Epoch 9.63 ... Loss 0.654 ... Acc 1.000
# ... Iteration 12610 ... Epoch 9.64 ... Loss 0.662 ... Acc 1.000
# ... Iteration 12620 ... Epoch 9.65 ... Loss 0.725 ... Acc 0.000
# ... Iteration 12630 ... Epoch 9.66 ... Loss 0.685 ... Acc 1.000
# ... Iteration 12640 ... Epoch 9.66 ... Loss 0.705 ... Acc 0.000
# ... Iteration 12650 ... Epoch 9.67 ... Loss 0.692 ... Acc 1.000
# ... Iteration 12660 ... Epoch 9.68 ... Loss 0.693 ... Acc 1.000
# ... Iteration 12670 ... Epoch 9.69 ... Loss 0.694 ... Acc 0.000
# ... Iteration 12680 ... Epoch 9.69 ... Loss 0.685 ... Acc 1.000
# ... Iteration 12690 ... Epoch 9.70 ... Loss 0.661 ... Acc 1.000
# ... Iteration 12700 ... Epoch 9.71 ... Loss 0.678 ... Acc 1.000
# ... Iteration 12710 ... Epoch 9.72 ... Loss 0.673 ... Acc 1.000
# ... Iteration 12720 ... Epoch 9.72 ... Loss 0.726 ... Acc 0.000
# ... Iteration 12730 ... Epoch 9.73 ... Loss 0.681 ... Acc 1.000
# ... Iteration 12740 ... Epoch 9.74 ... Loss 0.694 ... Acc 0.000
# ... Iteration 12750 ... Epoch 9.75 ... Loss 0.683 ... Acc 1.000
# ... Iteration 12760 ... Epoch 9.76 ... Loss 0.664 ... Acc 1.000
# ... Iteration 12770 ... Epoch 9.76 ... Loss 0.648 ... Acc 1.000
# ... Iteration 12780 ... Epoch 9.77 ... Loss 0.715 ... Acc 0.000
# ... Iteration 12790 ... Epoch 9.78 ... Loss 0.689 ... Acc 1.000
# ... Iteration 12800 ... Epoch 9.79 ... Loss 0.720 ... Acc 0.000
# ... Iteration 12810 ... Epoch 9.79 ... Loss 0.649 ... Acc 1.000
# ... Iteration 12820 ... Epoch 9.80 ... Loss 0.608 ... Acc 1.000
# ... Iteration 12830 ... Epoch 9.81 ... Loss 0.607 ... Acc 1.000
# ... Iteration 12840 ... Epoch 9.82 ... Loss 0.778 ... Acc 0.000
# ... Iteration 12850 ... Epoch 9.82 ... Loss 0.741 ... Acc 0.000
# ... Iteration 12860 ... Epoch 9.83 ... Loss 0.712 ... Acc 0.000
# ... Iteration 12870 ... Epoch 9.84 ... Loss 0.692 ... Acc 1.000
# ... Iteration 12880 ... Epoch 9.85 ... Loss 0.715 ... Acc 0.000
# ... Iteration 12890 ... Epoch 9.85 ... Loss 0.692 ... Acc 1.000
# ... Iteration 12900 ... Epoch 9.86 ... Loss 0.658 ... Acc 1.000
# ... Iteration 12910 ... Epoch 9.87 ... Loss 0.732 ... Acc 0.000
# ... Iteration 12920 ... Epoch 9.88 ... Loss 0.660 ... Acc 1.000
# ... Iteration 12930 ... Epoch 9.89 ... Loss 0.751 ... Acc 0.000
# ... Iteration 12940 ... Epoch 9.89 ... Loss 0.746 ... Acc 0.000
# ... Iteration 12950 ... Epoch 9.90 ... Loss 0.713 ... Acc 0.000
# ... Iteration 12960 ... Epoch 9.91 ... Loss 0.693 ... Acc 1.000
# ... Iteration 12970 ... Epoch 9.92 ... Loss 0.727 ... Acc 0.000
# ... Iteration 12980 ... Epoch 9.92 ... Loss 0.762 ... Acc 0.000
# ... Iteration 12990 ... Epoch 9.93 ... Loss 0.783 ... Acc 0.000
# ... Iteration 13000 ... Epoch 9.94 ... Loss 0.608 ... Acc 1.000
# ... Iteration 13010 ... Epoch 9.95 ... Loss 0.760 ... Acc 0.000
# ... Iteration 13020 ... Epoch 9.95 ... Loss 0.623 ... Acc 1.000
# ... Iteration 13030 ... Epoch 9.96 ... Loss 0.610 ... Acc 1.000
# ... Iteration 13040 ... Epoch 9.97 ... Loss 0.785 ... Acc 0.000
# ... Iteration 13050 ... Epoch 9.98 ... Loss 0.793 ... Acc 0.000
# ... Iteration 13060 ... Epoch 9.98 ... Loss 0.571 ... Acc 1.000
# ... Iteration 13070 ... Epoch 9.99 ... Loss 0.860 ... Acc 0.000
# ... Iteration 13080 ... Epoch 10.00 ... Loss 0.551 ... Acc 1.000

# %% [markdown]
# ### Test

# %%
engine.validate("test")
# Out:
# Validating model on the test set
# Iteration : 0, Progress 0.0
# Iteration : 1, Progress 0.006097560975609756
# Iteration : 2, Progress 0.012195121951219513
# Iteration : 3, Progress 0.018292682926829267
# Iteration : 4, Progress 0.024390243902439025
# Iteration : 5, Progress 0.03048780487804878
# Iteration : 6, Progress 0.036585365853658534
# Iteration : 7, Progress 0.042682926829268296
# Iteration : 8, Progress 0.04878048780487805
# Iteration : 9, Progress 0.054878048780487805
# Iteration : 10, Progress 0.06097560975609756
# Iteration : 11, Progress 0.06707317073170732
# Iteration : 12, Progress 0.07317073170731707
# Iteration : 13, Progress 0.07926829268292683
# Iteration : 14, Progress 0.08536585365853659
# Iteration : 15, Progress 0.09146341463414634
# Iteration : 16, Progress 0.0975609756097561
# Iteration : 17, Progress 0.10365853658536585
# Iteration : 18, Progress 0.10975609756097561
# Iteration : 19, Progress 0.11585365853658537
# Iteration : 20, Progress 0.12195121951219512
# Iteration : 21, Progress 0.12804878048780488
# Iteration : 22, Progress 0.13414634146341464
# Iteration : 23, Progress 0.1402439024390244
# Iteration : 24, Progress 0.14634146341463414
# Iteration : 25, Progress 0.1524390243902439
# Iteration : 26, Progress 0.15853658536585366
# Iteration : 27, Progress 0.16463414634146342
# Iteration : 28, Progress 0.17073170731707318
# Iteration : 29, Progress 0.17682926829268292
# Iteration : 30, Progress 0.18292682926829268
# Iteration : 31, Progress 0.18902439024390244
# Iteration : 32, Progress 0.1951219512195122
# Iteration : 33, Progress 0.20121951219512196
# Iteration : 34, Progress 0.2073170731707317
# Iteration : 35, Progress 0.21341463414634146
# Iteration : 36, Progress 0.21951219512195122
# Iteration : 37, Progress 0.22560975609756098
# Iteration : 38, Progress 0.23170731707317074
# Iteration : 39, Progress 0.23780487804878048
# Iteration : 40, Progress 0.24390243902439024
# Iteration : 41, Progress 0.25
# Iteration : 42, Progress 0.25609756097560976
# Iteration : 43, Progress 0.2621951219512195
# Iteration : 44, Progress 0.2682926829268293
# Iteration : 45, Progress 0.27439024390243905
# Iteration : 46, Progress 0.2804878048780488
# Iteration : 47, Progress 0.2865853658536585
# Iteration : 48, Progress 0.2926829268292683
# Iteration : 49, Progress 0.29878048780487804
# Iteration : 50, Progress 0.3048780487804878
# Iteration : 51, Progress 0.31097560975609756
# Iteration : 52, Progress 0.3170731707317073
# Iteration : 53, Progress 0.3231707317073171
# Iteration : 54, Progress 0.32926829268292684
# Iteration : 55, Progress 0.3353658536585366
# Iteration : 56, Progress 0.34146341463414637
# Iteration : 57, Progress 0.3475609756097561
# Iteration : 58, Progress 0.35365853658536583
# Iteration : 59, Progress 0.3597560975609756
# Iteration : 60, Progress 0.36585365853658536
# Iteration : 61, Progress 0.3719512195121951
# Iteration : 62, Progress 0.3780487804878049
# Iteration : 63, Progress 0.38414634146341464
# Iteration : 64, Progress 0.3902439024390244
# Iteration : 65, Progress 0.39634146341463417
# Iteration : 66, Progress 0.4024390243902439
# Iteration : 67, Progress 0.40853658536585363
# Iteration : 68, Progress 0.4146341463414634
# Iteration : 69, Progress 0.42073170731707316
# Iteration : 70, Progress 0.4268292682926829
# Iteration : 71, Progress 0.4329268292682927
# Iteration : 72, Progress 0.43902439024390244
# Iteration : 73, Progress 0.4451219512195122
# Iteration : 74, Progress 0.45121951219512196
# Iteration : 75, Progress 0.4573170731707317
# Iteration : 76, Progress 0.4634146341463415
# Iteration : 77, Progress 0.4695121951219512
# Iteration : 78, Progress 0.47560975609756095
# Iteration : 79, Progress 0.4817073170731707
# Iteration : 80, Progress 0.4878048780487805
# Iteration : 81, Progress 0.49390243902439024
# Iteration : 82, Progress 0.5
# Iteration : 83, Progress 0.5060975609756098
# Iteration : 84, Progress 0.5121951219512195
# Iteration : 85, Progress 0.5182926829268293
# Iteration : 86, Progress 0.524390243902439
# Iteration : 87, Progress 0.5304878048780488
# Iteration : 88, Progress 0.5365853658536586
# Iteration : 89, Progress 0.5426829268292683
# Iteration : 90, Progress 0.5487804878048781
# Iteration : 91, Progress 0.5548780487804879
# Iteration : 92, Progress 0.5609756097560976
# Iteration : 93, Progress 0.5670731707317073
# Iteration : 94, Progress 0.573170731707317
# Iteration : 95, Progress 0.5792682926829268
# Iteration : 96, Progress 0.5853658536585366
# Iteration : 97, Progress 0.5914634146341463
# Iteration : 98, Progress 0.5975609756097561
# Iteration : 99, Progress 0.6036585365853658
# Iteration : 100, Progress 0.6097560975609756
# Iteration : 101, Progress 0.6158536585365854
# Iteration : 102, Progress 0.6219512195121951
# Iteration : 103, Progress 0.6280487804878049
# Iteration : 104, Progress 0.6341463414634146
# Iteration : 105, Progress 0.6402439024390244
# Iteration : 106, Progress 0.6463414634146342
# Iteration : 107, Progress 0.6524390243902439
# Iteration : 108, Progress 0.6585365853658537
# Iteration : 109, Progress 0.6646341463414634
# Iteration : 110, Progress 0.6707317073170732
# Iteration : 111, Progress 0.676829268292683
# Iteration : 112, Progress 0.6829268292682927
# Iteration : 113, Progress 0.6890243902439024
# Iteration : 114, Progress 0.6951219512195121
# Iteration : 115, Progress 0.7012195121951219
# Iteration : 116, Progress 0.7073170731707317
# Iteration : 117, Progress 0.7134146341463414
# Iteration : 118, Progress 0.7195121951219512
# Iteration : 119, Progress 0.725609756097561
# Iteration : 120, Progress 0.7317073170731707
# Iteration : 121, Progress 0.7378048780487805
# Iteration : 122, Progress 0.7439024390243902
# Iteration : 123, Progress 0.75
# Iteration : 124, Progress 0.7560975609756098
# Iteration : 125, Progress 0.7621951219512195
# Iteration : 126, Progress 0.7682926829268293
# Iteration : 127, Progress 0.774390243902439
# Iteration : 128, Progress 0.7804878048780488
# Iteration : 129, Progress 0.7865853658536586
# Iteration : 130, Progress 0.7926829268292683
# Iteration : 131, Progress 0.7987804878048781
# Iteration : 132, Progress 0.8048780487804879
# Iteration : 133, Progress 0.8109756097560976
# Iteration : 134, Progress 0.8170731707317073
# Iteration : 135, Progress 0.823170731707317
# Iteration : 136, Progress 0.8292682926829268
# Iteration : 137, Progress 0.8353658536585366
# Iteration : 138, Progress 0.8414634146341463
# Iteration : 139, Progress 0.8475609756097561
# Iteration : 140, Progress 0.8536585365853658
# Iteration : 141, Progress 0.8597560975609756
# Iteration : 142, Progress 0.8658536585365854
# Iteration : 143, Progress 0.8719512195121951
# Iteration : 144, Progress 0.8780487804878049
# Iteration : 145, Progress 0.8841463414634146
# Iteration : 146, Progress 0.8902439024390244
# Iteration : 147, Progress 0.8963414634146342
# Iteration : 148, Progress 0.9024390243902439
# Iteration : 149, Progress 0.9085365853658537
# Iteration : 150, Progress 0.9146341463414634
# Iteration : 151, Progress 0.9207317073170732
# Iteration : 152, Progress 0.926829268292683
# Iteration : 153, Progress 0.9329268292682927
# Iteration : 154, Progress 0.9390243902439024
# Iteration : 155, Progress 0.9451219512195121
# Iteration : 156, Progress 0.9512195121951219
# Iteration : 157, Progress 0.9573170731707317
# Iteration : 158, Progress 0.9634146341463414
# Iteration : 159, Progress 0.9695121951219512
# Iteration : 160, Progress 0.975609756097561
# Iteration : 161, Progress 0.9817073170731707
# Iteration : 162, Progress 0.9878048780487805
# Iteration : 163, Progress 0.9939024390243902

# %% [markdown]
# ### Save and Load

# %%
engine.save_state()

# %%
model.conv1.weight
# Out:
# Parameter containing:
# tensor([[-0.2022, -0.3764, -0.1560, -0.1571, -0.2977,  0.0726,  0.4064,  0.0673,
#          -0.4541, -0.1497,  0.2524, -0.1232, -0.7010, -0.4255, -0.2545, -0.3702],
#         [-0.4060, -0.1885, -0.1186, -0.2231, -0.2302, -0.2523, -0.1852, -0.2108,
#          -0.2764, -0.0751, -0.2591,  0.6272, -0.2774, -0.3769, -0.2426, -0.2058],
#         [-0.0785, -0.4351, -0.1136,  0.4038, -0.2329,  0.3133,  0.0311,  0.1175,
#           0.4586, -0.0597, -0.2328,  0.3186, -0.3812, -0.1632, -0.0734,  0.2514],
#         [-0.3851,  0.5569,  0.4015,  0.1767,  0.4602,  0.3272, -0.0915,  0.1819,
#          -0.3966, -0.2142, -0.0629,  0.2916,  0.1185,  0.3014,  0.2812,  0.0142],
#         [-0.4202,  0.0276, -0.0707, -0.1376, -0.1610, -0.2124, -0.3863,  0.1287,
#          -0.3163, -0.0547, -0.1826, -0.1627,  0.1016, -0.4186, -0.0992, -0.3123],
#         [-0.3600,  0.7437,  0.0240,  0.2668, -0.4308, -0.4151,  0.0286, -0.0015,
#           0.4695,  0.1462,  0.4536, -0.5511, -0.5494,  0.4633,  0.3983, -0.0885],
#         [ 0.0465,  0.1794,  0.0543,  0.3541,  0.1448, -0.4387,  0.1819,  0.0182,
#          -0.0281,  0.1393, -0.6125,  0.1830,  0.0898,  0.4544, -0.0928, -0.0617],
#         [ 0.0882, -0.3553, -0.3192,  0.3491,  0.0414,  0.0554, -0.2747, -0.0228,
#          -0.1688, -0.2579, -0.4631, -0.1486,  0.4836,  0.1930, -0.0511,  0.2224]],
#        device='cuda:0', requires_grad=True)

# %%
model.conv1.weight = torch.nn.Parameter(torch.Tensor(np.random.rand(8,16)))
model.conv1.weight
# Out:
# Parameter containing:
# tensor([[0.6157, 0.2432, 0.8556, 0.3369, 0.3435, 0.7384, 0.5346, 0.1591, 0.8238,
#          0.6595, 0.6798, 0.2926, 0.9120, 0.5067, 0.8086, 0.7089],
#         [0.8408, 0.2373, 0.4983, 0.8418, 0.7784, 0.7952, 0.4930, 0.4700, 0.7724,
#          0.7797, 0.6266, 0.4994, 0.3589, 0.2786, 0.7338, 0.8408],
#         [0.5454, 0.5598, 0.3705, 0.9656, 0.0321, 0.6190, 0.9263, 0.2375, 0.3505,
#          0.2175, 0.5283, 0.8647, 0.0730, 0.4041, 0.2601, 0.9593],
#         [0.9331, 0.7923, 0.7750, 0.0777, 0.7771, 0.7115, 0.1746, 0.7311, 0.8464,
#          0.8135, 0.3760, 0.0310, 0.6498, 0.1042, 0.1139, 0.2601],
#         [0.9262, 0.9690, 0.4995, 0.4369, 0.4268, 0.2747, 0.8708, 0.1315, 0.2535,
#          0.0839, 0.0761, 0.1398, 0.3198, 0.0541, 0.7726, 0.4492],
#         [0.5795, 0.4856, 0.6194, 0.8952, 0.9648, 0.6960, 0.3843, 0.3602, 0.8442,
#          0.4476, 0.9379, 0.0793, 0.4839, 0.3902, 0.6733, 0.1277],
#         [0.4628, 0.1021, 0.2197, 0.0258, 0.9070, 0.3676, 0.2146, 0.7431, 0.8067,
#          0.1221, 0.1442, 0.6992, 0.8173, 0.0681, 0.6683, 0.7526],
#         [0.9798, 0.4879, 0.3953, 0.5631, 0.4504, 0.3854, 0.7617, 0.0309, 0.4420,
#          0.9456, 0.8503, 0.7216, 0.6975, 0.1625, 0.8199, 0.4820]],
#        requires_grad=True)

# %%
engine.load_state(osp.join(engine.dirpath, "gcn_kipf_latest.pth"))
# Out:
# Loading weights from file : dump20200203_101737/gcn_kipf_latest.pth
# Loading weights for module =  conv1
# Loading weights for module =  conv2
# Loading weights for module =  conv3

# %%
model.conv1.weight
# Out:
# Parameter containing:
# tensor([[-0.2022, -0.3764, -0.1560, -0.1571, -0.2977,  0.0726,  0.4064,  0.0673,
#          -0.4541, -0.1497,  0.2524, -0.1232, -0.7010, -0.4255, -0.2545, -0.3702],
#         [-0.4060, -0.1885, -0.1186, -0.2231, -0.2302, -0.2523, -0.1852, -0.2108,
#          -0.2764, -0.0751, -0.2591,  0.6272, -0.2774, -0.3769, -0.2426, -0.2058],
#         [-0.0785, -0.4351, -0.1136,  0.4038, -0.2329,  0.3133,  0.0311,  0.1175,
#           0.4586, -0.0597, -0.2328,  0.3186, -0.3812, -0.1632, -0.0734,  0.2514],
#         [-0.3851,  0.5569,  0.4015,  0.1767,  0.4602,  0.3272, -0.0915,  0.1819,
#          -0.3966, -0.2142, -0.0629,  0.2916,  0.1185,  0.3014,  0.2812,  0.0142],
#         [-0.4202,  0.0276, -0.0707, -0.1376, -0.1610, -0.2124, -0.3863,  0.1287,
#          -0.3163, -0.0547, -0.1826, -0.1627,  0.1016, -0.4186, -0.0992, -0.3123],
#         [-0.3600,  0.7437,  0.0240,  0.2668, -0.4308, -0.4151,  0.0286, -0.0015,
#           0.4695,  0.1462,  0.4536, -0.5511, -0.5494,  0.4633,  0.3983, -0.0885],
#         [ 0.0465,  0.1794,  0.0543,  0.3541,  0.1448, -0.4387,  0.1819,  0.0182,
#          -0.0281,  0.1393, -0.6125,  0.1830,  0.0898,  0.4544, -0.0928, -0.0617],
#         [ 0.0882, -0.3553, -0.3192,  0.3491,  0.0414,  0.0554, -0.2747, -0.0228,
#          -0.1688, -0.2579, -0.4631, -0.1486,  0.4836,  0.1930, -0.0511,  0.2224]],
#        device='cuda:0', requires_grad=True)

# %% [markdown]
# ### Model works after loading

# %%
engine.validate("test")
# Out:
# Validating model on the test set
# Iteration : 0, Progress 0.0
# Iteration : 1, Progress 0.006097560975609756
# Iteration : 2, Progress 0.012195121951219513
# Iteration : 3, Progress 0.018292682926829267
# Iteration : 4, Progress 0.024390243902439025
# Iteration : 5, Progress 0.03048780487804878
# Iteration : 6, Progress 0.036585365853658534
# Iteration : 7, Progress 0.042682926829268296
# Iteration : 8, Progress 0.04878048780487805
# Iteration : 9, Progress 0.054878048780487805
# Iteration : 10, Progress 0.06097560975609756
# Iteration : 11, Progress 0.06707317073170732
# Iteration : 12, Progress 0.07317073170731707
# Iteration : 13, Progress 0.07926829268292683
# Iteration : 14, Progress 0.08536585365853659
# Iteration : 15, Progress 0.09146341463414634
# Iteration : 16, Progress 0.0975609756097561
# Iteration : 17, Progress 0.10365853658536585
# Iteration : 18, Progress 0.10975609756097561
# Iteration : 19, Progress 0.11585365853658537
# Iteration : 20, Progress 0.12195121951219512
# Iteration : 21, Progress 0.12804878048780488
# Iteration : 22, Progress 0.13414634146341464
# Iteration : 23, Progress 0.1402439024390244
# Iteration : 24, Progress 0.14634146341463414
# Iteration : 25, Progress 0.1524390243902439
# Iteration : 26, Progress 0.15853658536585366
# Iteration : 27, Progress 0.16463414634146342
# Iteration : 28, Progress 0.17073170731707318
# Iteration : 29, Progress 0.17682926829268292
# Iteration : 30, Progress 0.18292682926829268
# Iteration : 31, Progress 0.18902439024390244
# Iteration : 32, Progress 0.1951219512195122
# Iteration : 33, Progress 0.20121951219512196
# Iteration : 34, Progress 0.2073170731707317
# Iteration : 35, Progress 0.21341463414634146
# Iteration : 36, Progress 0.21951219512195122
# Iteration : 37, Progress 0.22560975609756098
# Iteration : 38, Progress 0.23170731707317074
# Iteration : 39, Progress 0.23780487804878048
# Iteration : 40, Progress 0.24390243902439024
# Iteration : 41, Progress 0.25
# Iteration : 42, Progress 0.25609756097560976
# Iteration : 43, Progress 0.2621951219512195
# Iteration : 44, Progress 0.2682926829268293
# Iteration : 45, Progress 0.27439024390243905
# Iteration : 46, Progress 0.2804878048780488
# Iteration : 47, Progress 0.2865853658536585
# Iteration : 48, Progress 0.2926829268292683
# Iteration : 49, Progress 0.29878048780487804
# Iteration : 50, Progress 0.3048780487804878
# Iteration : 51, Progress 0.31097560975609756
# Iteration : 52, Progress 0.3170731707317073
# Iteration : 53, Progress 0.3231707317073171
# Iteration : 54, Progress 0.32926829268292684
# Iteration : 55, Progress 0.3353658536585366
# Iteration : 56, Progress 0.34146341463414637
# Iteration : 57, Progress 0.3475609756097561
# Iteration : 58, Progress 0.35365853658536583
# Iteration : 59, Progress 0.3597560975609756
# Iteration : 60, Progress 0.36585365853658536
# Iteration : 61, Progress 0.3719512195121951
# Iteration : 62, Progress 0.3780487804878049
# Iteration : 63, Progress 0.38414634146341464
# Iteration : 64, Progress 0.3902439024390244
# Iteration : 65, Progress 0.39634146341463417
# Iteration : 66, Progress 0.4024390243902439
# Iteration : 67, Progress 0.40853658536585363
# Iteration : 68, Progress 0.4146341463414634
# Iteration : 69, Progress 0.42073170731707316
# Iteration : 70, Progress 0.4268292682926829
# Iteration : 71, Progress 0.4329268292682927
# Iteration : 72, Progress 0.43902439024390244
# Iteration : 73, Progress 0.4451219512195122
# Iteration : 74, Progress 0.45121951219512196
# Iteration : 75, Progress 0.4573170731707317
# Iteration : 76, Progress 0.4634146341463415
# Iteration : 77, Progress 0.4695121951219512
# Iteration : 78, Progress 0.47560975609756095
# Iteration : 79, Progress 0.4817073170731707
# Iteration : 80, Progress 0.4878048780487805
# Iteration : 81, Progress 0.49390243902439024
# Iteration : 82, Progress 0.5
# Iteration : 83, Progress 0.5060975609756098
# Iteration : 84, Progress 0.5121951219512195
# Iteration : 85, Progress 0.5182926829268293
# Iteration : 86, Progress 0.524390243902439
# Iteration : 87, Progress 0.5304878048780488
# Iteration : 88, Progress 0.5365853658536586
# Iteration : 89, Progress 0.5426829268292683
# Iteration : 90, Progress 0.5487804878048781
# Iteration : 91, Progress 0.5548780487804879
# Iteration : 92, Progress 0.5609756097560976
# Iteration : 93, Progress 0.5670731707317073
# Iteration : 94, Progress 0.573170731707317
# Iteration : 95, Progress 0.5792682926829268
# Iteration : 96, Progress 0.5853658536585366
# Iteration : 97, Progress 0.5914634146341463
# Iteration : 98, Progress 0.5975609756097561
# Iteration : 99, Progress 0.6036585365853658
# Iteration : 100, Progress 0.6097560975609756
# Iteration : 101, Progress 0.6158536585365854
# Iteration : 102, Progress 0.6219512195121951
# Iteration : 103, Progress 0.6280487804878049
# Iteration : 104, Progress 0.6341463414634146
# Iteration : 105, Progress 0.6402439024390244
# Iteration : 106, Progress 0.6463414634146342
# Iteration : 107, Progress 0.6524390243902439
# Iteration : 108, Progress 0.6585365853658537
# Iteration : 109, Progress 0.6646341463414634
# Iteration : 110, Progress 0.6707317073170732
# Iteration : 111, Progress 0.676829268292683
# Iteration : 112, Progress 0.6829268292682927
# Iteration : 113, Progress 0.6890243902439024
# Iteration : 114, Progress 0.6951219512195121
# Iteration : 115, Progress 0.7012195121951219
# Iteration : 116, Progress 0.7073170731707317
# Iteration : 117, Progress 0.7134146341463414
# Iteration : 118, Progress 0.7195121951219512
# Iteration : 119, Progress 0.725609756097561
# Iteration : 120, Progress 0.7317073170731707
# Iteration : 121, Progress 0.7378048780487805
# Iteration : 122, Progress 0.7439024390243902
# Iteration : 123, Progress 0.75
# Iteration : 124, Progress 0.7560975609756098
# Iteration : 125, Progress 0.7621951219512195
# Iteration : 126, Progress 0.7682926829268293
# Iteration : 127, Progress 0.774390243902439
# Iteration : 128, Progress 0.7804878048780488
# Iteration : 129, Progress 0.7865853658536586
# Iteration : 130, Progress 0.7926829268292683
# Iteration : 131, Progress 0.7987804878048781
# Iteration : 132, Progress 0.8048780487804879
# Iteration : 133, Progress 0.8109756097560976
# Iteration : 134, Progress 0.8170731707317073
# Iteration : 135, Progress 0.823170731707317
# Iteration : 136, Progress 0.8292682926829268
# Iteration : 137, Progress 0.8353658536585366
# Iteration : 138, Progress 0.8414634146341463
# Iteration : 139, Progress 0.8475609756097561
# Iteration : 140, Progress 0.8536585365853658
# Iteration : 141, Progress 0.8597560975609756
# Iteration : 142, Progress 0.8658536585365854
# Iteration : 143, Progress 0.8719512195121951
# Iteration : 144, Progress 0.8780487804878049
# Iteration : 145, Progress 0.8841463414634146
# Iteration : 146, Progress 0.8902439024390244
# Iteration : 147, Progress 0.8963414634146342
# Iteration : 148, Progress 0.9024390243902439
# Iteration : 149, Progress 0.9085365853658537
# Iteration : 150, Progress 0.9146341463414634
# Iteration : 151, Progress 0.9207317073170732
# Iteration : 152, Progress 0.926829268292683
# Iteration : 153, Progress 0.9329268292682927
# Iteration : 154, Progress 0.9390243902439024
# Iteration : 155, Progress 0.9451219512195121
# Iteration : 156, Progress 0.9512195121951219
# Iteration : 157, Progress 0.9573170731707317
# Iteration : 158, Progress 0.9634146341463414
# Iteration : 159, Progress 0.9695121951219512
# Iteration : 160, Progress 0.975609756097561
# Iteration : 161, Progress 0.9817073170731707
# Iteration : 162, Progress 0.9878048780487805
# Iteration : 163, Progress 0.9939024390243902
